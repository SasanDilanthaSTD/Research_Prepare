# %% [markdown]
# ### Import packeges

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import rasterio
from sklearn.model_selection import KFold, GridSearchCV
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report, f1_score, precision_score, recall_score, confusion_matrix
import joblib 
from pathlib import Path

# %%
# define ouput dir
output_dir = Path("../output/XGBoost")
output_dir.mkdir(parents=True, exist_ok=True)

output_img_dir = output_dir / "IMG"
output_img_dir.mkdir(parents=True, exist_ok=True)

output_model_dir = output_dir / "model"
output_model_dir.mkdir(parents=True, exist_ok=True)

# %%
# Define functions to calculate NDVI and NDWI
def calculate_ndvi(nir, red):
    return (nir - red) / (nir + red + 1e-10)

def calculate_ndwi(nir, green):
    return (nir - green) / (nir + green + 1e-10)

# Function to extract mean NDVI & NDWI as features
def extract_features(image_path):
    with rasterio.open(image_path) as src:
        bands = src.read()
        nir, red, green = bands[3], bands[0], bands[1]   # Adjust based on band order
        
        ndvi = calculate_ndvi(nir, red)
        ndwi = calculate_ndwi(nir, green)

        return [np.mean(ndvi), np.mean(ndwi)]  # Use mean as feature

# %%
growth_stages = ["germination", "tillering", "grand_growth", "ripening"]

# %%
# Load dataset efficiently
train_dataset_path = Path('../../../../data/odm_dataset/Patches/Train')
test_dataset_path = Path('../../../../data/odm_dataset/Patches/Test/')
growth_stages = ["germination", "tillering", "grand_growth", "ripening"]
X, X_test, y, y_test = [], [], [], []

for idx, stage in enumerate(growth_stages):
    stage_path = train_dataset_path / stage
    for img_file in os.listdir(stage_path):
        img_path = stage_path / img_file
        X.append(extract_features(img_path))
        y.append(idx)

X = np.array(X)
y = np.array(y)

for idx, stage in enumerate(growth_stages):
    stage_path = test_dataset_path / stage
    for img_file in os.listdir(stage_path):
        img_path = stage_path / img_file
        X_test.append(extract_features(img_path))
        y_test.append(idx)

X_test = np.array(X_test)
y_test = np.array(y_test)

# %% [markdown]
# #### Apply k-Fold Cross-Validation and GridSearchCV

# %%
# Define parameter grid for XGBoost
param_grid = {
    "n_estimators": [50, 100, 200],
    "max_depth": [3, 6, 10],
    "learning_rate": [0.01, 0.1, 0.2],
    "subsample": [0.8, 1.0],
    "colsample_bytree": [0.8, 1.0]
}

# Initialize XGBoost and GridSearchCV
xgb_model = XGBClassifier(use_label_encoder=False, eval_metric='mlogloss', random_state=42)
kf = KFold(n_splits=5, shuffle=True, random_state=42)

grid_search = GridSearchCV(xgb_model, param_grid, cv=kf, n_jobs=-1, verbose=2, return_train_score=True)

# Train model with cross-validation
grid_search.fit(X, y)

# Get the best model from Grid Search
best_model = grid_search.best_estimator_

# Best parameters
print(f"Best Parameters: {grid_search.best_params_}")

# Train the model on the entire training dataset
history = best_model.fit(X, y, eval_set=[(X, y), (X_test, y_test)], verbose=True)

# Plot training and test accuracy
eval_results = best_model.evals_result()
train_accuracy = eval_results['validation_0']['mlogloss']
test_accuracy = eval_results['validation_1']['mlogloss']

plt.figure(figsize=(8, 6))
plt.plot(train_accuracy, label='Train Accuracy')
plt.plot(test_accuracy, label='Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Log Loss')
plt.title('Training vs Test Accuracy')
plt.legend()
plt.savefig(Path(os.path.join(output_img_dir, "ODM_XGB_V2_accuracy_plot.png")))
plt.show()
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# Best Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 200, 'subsample': 0.8}
# [0]	validation_0-mlogloss:1.37864	validation_1-mlogloss:1.37974
# c:\Users\user\anaconda3\envs\research_env\lib\site-packages\xgboost\core.py:158: UserWarning: [17:05:09] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [1]	validation_0-mlogloss:1.37105	validation_1-mlogloss:1.37295
# [2]	validation_0-mlogloss:1.36345	validation_1-mlogloss:1.36612
# [3]	validation_0-mlogloss:1.35610	validation_1-mlogloss:1.35965
# [4]	validation_0-mlogloss:1.34881	validation_1-mlogloss:1.35322
# [5]	validation_0-mlogloss:1.34163	validation_1-mlogloss:1.34695
# [6]	validation_0-mlogloss:1.33464	validation_1-mlogloss:1.34064
# [7]	validation_0-mlogloss:1.32778	validation_1-mlogloss:1.33470
# [8]	validation_0-mlogloss:1.32082	validation_1-mlogloss:1.32841
# [9]	validation_0-mlogloss:1.31390	validation_1-mlogloss:1.32230
# [10]	validation_0-mlogloss:1.30730	validation_1-mlogloss:1.31659
# [11]	validation_0-mlogloss:1.30059	validation_1-mlogloss:1.31080
# [12]	validation_0-mlogloss:1.29411	validation_1-mlogloss:1.30512
# [13]	validation_0-mlogloss:1.28785	validation_1-mlogloss:1.29962
# [14]	validation_0-mlogloss:1.28162	validation_1-mlogloss:1.29405
# [15]	validation_0-mlogloss:1.27534	validation_1-mlogloss:1.28869
# [16]	validation_0-mlogloss:1.26915	validation_1-mlogloss:1.28337
# [17]	validation_0-mlogloss:1.26309	validation_1-mlogloss:1.27810
# [18]	validation_0-mlogloss:1.25714	validation_1-mlogloss:1.27293
# [19]	validation_0-mlogloss:1.25115	validation_1-mlogloss:1.26753
# [20]	validation_0-mlogloss:1.24532	validation_1-mlogloss:1.26238
# [21]	validation_0-mlogloss:1.23964	validation_1-mlogloss:1.25738
# [22]	validation_0-mlogloss:1.23393	validation_1-mlogloss:1.25252
# [23]	validation_0-mlogloss:1.22830	validation_1-mlogloss:1.24766
# [24]	validation_0-mlogloss:1.22280	validation_1-mlogloss:1.24272
# [25]	validation_0-mlogloss:1.21737	validation_1-mlogloss:1.23790
# [26]	validation_0-mlogloss:1.21215	validation_1-mlogloss:1.23344
# [27]	validation_0-mlogloss:1.20688	validation_1-mlogloss:1.22895
# [28]	validation_0-mlogloss:1.20165	validation_1-mlogloss:1.22442
# [29]	validation_0-mlogloss:1.19657	validation_1-mlogloss:1.21985
# [30]	validation_0-mlogloss:1.19149	validation_1-mlogloss:1.21544
# [31]	validation_0-mlogloss:1.18640	validation_1-mlogloss:1.21097
# [32]	validation_0-mlogloss:1.18142	validation_1-mlogloss:1.20654
# [33]	validation_0-mlogloss:1.17637	validation_1-mlogloss:1.20224
# [34]	validation_0-mlogloss:1.17151	validation_1-mlogloss:1.19809
# [35]	validation_0-mlogloss:1.16664	validation_1-mlogloss:1.19395
# [36]	validation_0-mlogloss:1.16200	validation_1-mlogloss:1.19000
# [37]	validation_0-mlogloss:1.15723	validation_1-mlogloss:1.18577
# [38]	validation_0-mlogloss:1.15268	validation_1-mlogloss:1.18172
# [39]	validation_0-mlogloss:1.14801	validation_1-mlogloss:1.17780
# [40]	validation_0-mlogloss:1.14359	validation_1-mlogloss:1.17397
# [41]	validation_0-mlogloss:1.13908	validation_1-mlogloss:1.17003
# [42]	validation_0-mlogloss:1.13477	validation_1-mlogloss:1.16642
# [43]	validation_0-mlogloss:1.13035	validation_1-mlogloss:1.16261
# [44]	validation_0-mlogloss:1.12610	validation_1-mlogloss:1.15906
# [45]	validation_0-mlogloss:1.12179	validation_1-mlogloss:1.15547
# [46]	validation_0-mlogloss:1.11759	validation_1-mlogloss:1.15202
# [47]	validation_0-mlogloss:1.11345	validation_1-mlogloss:1.14841
# [48]	validation_0-mlogloss:1.10948	validation_1-mlogloss:1.14501
# [49]	validation_0-mlogloss:1.10533	validation_1-mlogloss:1.14152
# [50]	validation_0-mlogloss:1.10131	validation_1-mlogloss:1.13799
# [51]	validation_0-mlogloss:1.09724	validation_1-mlogloss:1.13465
# [52]	validation_0-mlogloss:1.09331	validation_1-mlogloss:1.13135
# [53]	validation_0-mlogloss:1.08957	validation_1-mlogloss:1.12799
# [54]	validation_0-mlogloss:1.08570	validation_1-mlogloss:1.12472
# [55]	validation_0-mlogloss:1.08189	validation_1-mlogloss:1.12148
# [56]	validation_0-mlogloss:1.07816	validation_1-mlogloss:1.11856
# [57]	validation_0-mlogloss:1.07450	validation_1-mlogloss:1.11553
# [58]	validation_0-mlogloss:1.07084	validation_1-mlogloss:1.11232
# [59]	validation_0-mlogloss:1.06711	validation_1-mlogloss:1.10928
# [60]	validation_0-mlogloss:1.06353	validation_1-mlogloss:1.10634
# [61]	validation_0-mlogloss:1.05994	validation_1-mlogloss:1.10333
# [62]	validation_0-mlogloss:1.05650	validation_1-mlogloss:1.10061
# [63]	validation_0-mlogloss:1.05303	validation_1-mlogloss:1.09776
# [64]	validation_0-mlogloss:1.04965	validation_1-mlogloss:1.09502
# [65]	validation_0-mlogloss:1.04627	validation_1-mlogloss:1.09215
# [66]	validation_0-mlogloss:1.04305	validation_1-mlogloss:1.08950
# [67]	validation_0-mlogloss:1.03977	validation_1-mlogloss:1.08680
# [68]	validation_0-mlogloss:1.03653	validation_1-mlogloss:1.08420
# [69]	validation_0-mlogloss:1.03334	validation_1-mlogloss:1.08148
# [70]	validation_0-mlogloss:1.03020	validation_1-mlogloss:1.07884
# [71]	validation_0-mlogloss:1.02698	validation_1-mlogloss:1.07614
# [72]	validation_0-mlogloss:1.02395	validation_1-mlogloss:1.07358
# [73]	validation_0-mlogloss:1.02083	validation_1-mlogloss:1.07103
# [74]	validation_0-mlogloss:1.01783	validation_1-mlogloss:1.06849
# [75]	validation_0-mlogloss:1.01483	validation_1-mlogloss:1.06586
# [76]	validation_0-mlogloss:1.01184	validation_1-mlogloss:1.06339
# [77]	validation_0-mlogloss:1.00887	validation_1-mlogloss:1.06084
# [78]	validation_0-mlogloss:1.00584	validation_1-mlogloss:1.05830
# [79]	validation_0-mlogloss:1.00285	validation_1-mlogloss:1.05585
# [80]	validation_0-mlogloss:0.99990	validation_1-mlogloss:1.05323
# [81]	validation_0-mlogloss:0.99704	validation_1-mlogloss:1.05081
# [82]	validation_0-mlogloss:0.99433	validation_1-mlogloss:1.04861
# [83]	validation_0-mlogloss:0.99151	validation_1-mlogloss:1.04633
# [84]	validation_0-mlogloss:0.98870	validation_1-mlogloss:1.04388
# [85]	validation_0-mlogloss:0.98593	validation_1-mlogloss:1.04152
# [86]	validation_0-mlogloss:0.98308	validation_1-mlogloss:1.03922
# [87]	validation_0-mlogloss:0.98046	validation_1-mlogloss:1.03706
# [88]	validation_0-mlogloss:0.97776	validation_1-mlogloss:1.03494
# [89]	validation_0-mlogloss:0.97514	validation_1-mlogloss:1.03284
# [90]	validation_0-mlogloss:0.97254	validation_1-mlogloss:1.03062
# [91]	validation_0-mlogloss:0.97002	validation_1-mlogloss:1.02859
# [92]	validation_0-mlogloss:0.96735	validation_1-mlogloss:1.02650
# [93]	validation_0-mlogloss:0.96479	validation_1-mlogloss:1.02457
# [94]	validation_0-mlogloss:0.96229	validation_1-mlogloss:1.02262
# [95]	validation_0-mlogloss:0.95977	validation_1-mlogloss:1.02063
# [96]	validation_0-mlogloss:0.95735	validation_1-mlogloss:1.01869
# [97]	validation_0-mlogloss:0.95496	validation_1-mlogloss:1.01680
# [98]	validation_0-mlogloss:0.95244	validation_1-mlogloss:1.01470
# [99]	validation_0-mlogloss:0.95001	validation_1-mlogloss:1.01279
# [100]	validation_0-mlogloss:0.94769	validation_1-mlogloss:1.01084
# [101]	validation_0-mlogloss:0.94542	validation_1-mlogloss:1.00917
# [102]	validation_0-mlogloss:0.94307	validation_1-mlogloss:1.00708
# [103]	validation_0-mlogloss:0.94083	validation_1-mlogloss:1.00524
# [104]	validation_0-mlogloss:0.93857	validation_1-mlogloss:1.00348
# [105]	validation_0-mlogloss:0.93635	validation_1-mlogloss:1.00176
# [106]	validation_0-mlogloss:0.93414	validation_1-mlogloss:1.00006
# [107]	validation_0-mlogloss:0.93191	validation_1-mlogloss:0.99835
# [108]	validation_0-mlogloss:0.92976	validation_1-mlogloss:0.99658
# [109]	validation_0-mlogloss:0.92764	validation_1-mlogloss:0.99511
# [110]	validation_0-mlogloss:0.92553	validation_1-mlogloss:0.99345
# [111]	validation_0-mlogloss:0.92338	validation_1-mlogloss:0.99168
# [112]	validation_0-mlogloss:0.92127	validation_1-mlogloss:0.99009
# [113]	validation_0-mlogloss:0.91924	validation_1-mlogloss:0.98839
# [114]	validation_0-mlogloss:0.91713	validation_1-mlogloss:0.98668
# [115]	validation_0-mlogloss:0.91507	validation_1-mlogloss:0.98494
# [116]	validation_0-mlogloss:0.91293	validation_1-mlogloss:0.98314
# [117]	validation_0-mlogloss:0.91091	validation_1-mlogloss:0.98166
# [118]	validation_0-mlogloss:0.90892	validation_1-mlogloss:0.98002
# [119]	validation_0-mlogloss:0.90693	validation_1-mlogloss:0.97852
# [120]	validation_0-mlogloss:0.90505	validation_1-mlogloss:0.97709
# [121]	validation_0-mlogloss:0.90308	validation_1-mlogloss:0.97559
# [122]	validation_0-mlogloss:0.90114	validation_1-mlogloss:0.97418
# [123]	validation_0-mlogloss:0.89923	validation_1-mlogloss:0.97281
# [124]	validation_0-mlogloss:0.89738	validation_1-mlogloss:0.97136
# [125]	validation_0-mlogloss:0.89555	validation_1-mlogloss:0.96989
# [126]	validation_0-mlogloss:0.89367	validation_1-mlogloss:0.96850
# [127]	validation_0-mlogloss:0.89192	validation_1-mlogloss:0.96703
# [128]	validation_0-mlogloss:0.89011	validation_1-mlogloss:0.96557
# [129]	validation_0-mlogloss:0.88830	validation_1-mlogloss:0.96424
# [130]	validation_0-mlogloss:0.88649	validation_1-mlogloss:0.96283
# [131]	validation_0-mlogloss:0.88467	validation_1-mlogloss:0.96134
# [132]	validation_0-mlogloss:0.88294	validation_1-mlogloss:0.96010
# [133]	validation_0-mlogloss:0.88125	validation_1-mlogloss:0.95891
# [134]	validation_0-mlogloss:0.87958	validation_1-mlogloss:0.95767
# [135]	validation_0-mlogloss:0.87785	validation_1-mlogloss:0.95641
# [136]	validation_0-mlogloss:0.87619	validation_1-mlogloss:0.95512
# [137]	validation_0-mlogloss:0.87449	validation_1-mlogloss:0.95382
# [138]	validation_0-mlogloss:0.87280	validation_1-mlogloss:0.95263
# [139]	validation_0-mlogloss:0.87116	validation_1-mlogloss:0.95146
# [140]	validation_0-mlogloss:0.86960	validation_1-mlogloss:0.95032
# [141]	validation_0-mlogloss:0.86803	validation_1-mlogloss:0.94916
# [142]	validation_0-mlogloss:0.86646	validation_1-mlogloss:0.94791
# [143]	validation_0-mlogloss:0.86488	validation_1-mlogloss:0.94670
# [144]	validation_0-mlogloss:0.86331	validation_1-mlogloss:0.94548
# [145]	validation_0-mlogloss:0.86173	validation_1-mlogloss:0.94418
# [146]	validation_0-mlogloss:0.86020	validation_1-mlogloss:0.94307
# [147]	validation_0-mlogloss:0.85874	validation_1-mlogloss:0.94198
# [148]	validation_0-mlogloss:0.85725	validation_1-mlogloss:0.94097
# [149]	validation_0-mlogloss:0.85569	validation_1-mlogloss:0.93971
# [150]	validation_0-mlogloss:0.85418	validation_1-mlogloss:0.93864
# [151]	validation_0-mlogloss:0.85272	validation_1-mlogloss:0.93752
# [152]	validation_0-mlogloss:0.85120	validation_1-mlogloss:0.93646
# [153]	validation_0-mlogloss:0.84973	validation_1-mlogloss:0.93527
# [154]	validation_0-mlogloss:0.84829	validation_1-mlogloss:0.93421
# [155]	validation_0-mlogloss:0.84688	validation_1-mlogloss:0.93314
# [156]	validation_0-mlogloss:0.84543	validation_1-mlogloss:0.93214
# [157]	validation_0-mlogloss:0.84401	validation_1-mlogloss:0.93117
# [158]	validation_0-mlogloss:0.84261	validation_1-mlogloss:0.93027
# [159]	validation_0-mlogloss:0.84122	validation_1-mlogloss:0.92919
# [160]	validation_0-mlogloss:0.83982	validation_1-mlogloss:0.92814
# [161]	validation_0-mlogloss:0.83849	validation_1-mlogloss:0.92718
# [162]	validation_0-mlogloss:0.83714	validation_1-mlogloss:0.92618
# [163]	validation_0-mlogloss:0.83583	validation_1-mlogloss:0.92520
# [164]	validation_0-mlogloss:0.83456	validation_1-mlogloss:0.92429
# [165]	validation_0-mlogloss:0.83326	validation_1-mlogloss:0.92345
# [166]	validation_0-mlogloss:0.83201	validation_1-mlogloss:0.92262
# [167]	validation_0-mlogloss:0.83071	validation_1-mlogloss:0.92171
# [168]	validation_0-mlogloss:0.82944	validation_1-mlogloss:0.92074
# [169]	validation_0-mlogloss:0.82820	validation_1-mlogloss:0.91984
# [170]	validation_0-mlogloss:0.82690	validation_1-mlogloss:0.91892
# [171]	validation_0-mlogloss:0.82560	validation_1-mlogloss:0.91795
# [172]	validation_0-mlogloss:0.82442	validation_1-mlogloss:0.91710
# [173]	validation_0-mlogloss:0.82321	validation_1-mlogloss:0.91620
# [174]	validation_0-mlogloss:0.82202	validation_1-mlogloss:0.91543
# [175]	validation_0-mlogloss:0.82083	validation_1-mlogloss:0.91466
# [176]	validation_0-mlogloss:0.81961	validation_1-mlogloss:0.91377
# [177]	validation_0-mlogloss:0.81838	validation_1-mlogloss:0.91298
# [178]	validation_0-mlogloss:0.81719	validation_1-mlogloss:0.91209
# [179]	validation_0-mlogloss:0.81601	validation_1-mlogloss:0.91135
# [180]	validation_0-mlogloss:0.81482	validation_1-mlogloss:0.91052
# [181]	validation_0-mlogloss:0.81368	validation_1-mlogloss:0.90985
# [182]	validation_0-mlogloss:0.81253	validation_1-mlogloss:0.90923
# [183]	validation_0-mlogloss:0.81137	validation_1-mlogloss:0.90840
# [184]	validation_0-mlogloss:0.81026	validation_1-mlogloss:0.90776
# [185]	validation_0-mlogloss:0.80918	validation_1-mlogloss:0.90704
# [186]	validation_0-mlogloss:0.80810	validation_1-mlogloss:0.90623
# [187]	validation_0-mlogloss:0.80700	validation_1-mlogloss:0.90555
# [188]	validation_0-mlogloss:0.80594	validation_1-mlogloss:0.90475
# [189]	validation_0-mlogloss:0.80490	validation_1-mlogloss:0.90401
# [190]	validation_0-mlogloss:0.80383	validation_1-mlogloss:0.90329
# [191]	validation_0-mlogloss:0.80277	validation_1-mlogloss:0.90247
# [192]	validation_0-mlogloss:0.80175	validation_1-mlogloss:0.90177
# [193]	validation_0-mlogloss:0.80070	validation_1-mlogloss:0.90098
# [194]	validation_0-mlogloss:0.79972	validation_1-mlogloss:0.90029
# [195]	validation_0-mlogloss:0.79867	validation_1-mlogloss:0.89959
# [196]	validation_0-mlogloss:0.79758	validation_1-mlogloss:0.89884
# [197]	validation_0-mlogloss:0.79657	validation_1-mlogloss:0.89825
# [198]	validation_0-mlogloss:0.79554	validation_1-mlogloss:0.89762
# [199]	validation_0-mlogloss:0.79452	validation_1-mlogloss:0.89688

# %% [markdown]
# #### Evaluate Model

# %%
# Evaluate the model on the test set
y_test_pred = best_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_test_pred)
test_report = classification_report(y_test, y_test_pred)

# Calculate additional metrics
test_precision = precision_score(y_test, y_test_pred, average='weighted')
test_recall = recall_score(y_test, y_test_pred, average='weighted')
test_f1 = f1_score(y_test, y_test_pred, average='weighted')
confusion = confusion_matrix(y_test, y_test_pred)

# Log confusion matrix as an image
plt.figure(figsize=(8, 6))
sns.heatmap(confusion, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.savefig(Path(os.path.join(output_img_dir, "ODM_XGB_V2_confusion_matrix.png"))) # Save confusion matrix

# Print results
print(f"Test Accuracy: {test_accuracy}")
print(f"Test Precision: {test_precision}")
print(f"Test Recall: {test_recall}")
print(f"Test F1 Score: {test_f1}")
print(f"Classification Report:\n{test_report}")

# Save the best model to disk
XGB_model_v2 = Path(os.path.join(output_model_dir, "XGB_model_v2.joblib"))
joblib.dump(best_model, XGB_model_v2)
print(f"Saved model to: {XGB_model_v2}")

# Evaluate using cross-validation accuracy
print(f"Best Cross-Validation Accuracy: {grid_search.best_score_ * 100:.2f}%")
# Out:
# Test Accuracy: 0.5894039735099338
# Test Precision: 0.5971596627061421
# Test Recall: 0.5894039735099338
# Test F1 Score: 0.5880409775203235
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.64      0.63      0.63        97
#            1       0.58      0.48      0.52        77
#            2       0.50      0.73      0.59        51
#            3       0.63      0.56      0.59        77
#
#     accuracy                           0.59       302
#    macro avg       0.59      0.60      0.59       302
# weighted avg       0.60      0.59      0.59       302
#
# Saved model to: ..\output\XGBoost\model\XGB_model_v2.joblib
# Best Cross-Validation Accuracy: 63.48%

# %% [markdown]
# #### Predict New Images

# %%
# Load the best model
model = joblib.load(Path(XGB_model_v2))

def predict_growth_stage(image_path, model):
    features = extract_features(image_path)
    predicted_label = model.predict([features])[0]
    return growth_stages[predicted_label]

new_image = Path('../../../../data/odm_dataset/Patches/Train/ripening/patch_66.tif')
predicted_stage = predict_growth_stage(new_image, model)
print(f"Predicted Growth Stage: {predicted_stage}")
print()
# Out:
# Predicted Growth Stage: ripening
