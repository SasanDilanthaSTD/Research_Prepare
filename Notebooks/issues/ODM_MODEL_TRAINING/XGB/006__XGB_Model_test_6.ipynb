# %% [markdown]
# ## XGBoost modifications
#  - V1 : Use SMOTE

# %% [markdown]
# >- import packages

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import rasterio
from sklearn.model_selection import KFold, GridSearchCV
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report, f1_score, precision_score, recall_score, confusion_matrix
import joblib 
from pathlib import Path

# for data leveling
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline

# for aumentation
from scipy.ndimage import rotate

# %% [markdown]
# >- Define function & modify

# %%
# define ouput dir
output_dir = Path("../output/XGBoost")
output_dir.mkdir(parents=True, exist_ok=True)

output_img_dir = output_dir / "IMG"
output_img_dir.mkdir(parents=True, exist_ok=True)

output_model_dir = output_dir / "model"
output_model_dir.mkdir(parents=True, exist_ok=True)

# %%
# Define functions to calculate NDVI and NDWI
def calculate_ndvi(nir, red):
    return (nir - red) / (nir + red + 1e-10)

def calculate_ndwi(nir, green):
    return (nir - green) / (nir + green + 1e-10)

# define data augmentation function
def augment_image(bands):
    """Perform augmentation on GeoTIFF bands (NIR, Red, Green)."""
    nir, red, green = bands[3], bands[0], bands[1]

    aug_bands = []
    # original
    aug_bands.append((nir, red, green))

    # Rotations (60,120,180, 240, 300) - keep shape same
    for angle in [60, 120, 180, 240, 300]:
        aug_bands.append((
            rotate(nir, angle, reshape=False),
            rotate(red, angle, reshape=False),
            rotate(green, angle, reshape=False)
        ))

    # Horizontal + vertical flips
    aug_bands.append((np.fliplr(nir), np.fliplr(red), np.fliplr(green)))
    aug_bands.append((np.flipud(nir), np.flipud(red), np.flipud(green)))

    # Small Gaussian noise (simulate sensor variation)
    noise = np.random.normal(0, 0.01, nir.shape).astype(nir.dtype)
    aug_bands.append((nir + noise, red + noise, green + noise))

    return aug_bands

'''
    Enhanced Feature Engineering:
        -  Current features (mean NDVI/NDWI) might be insufficient. Add:

'''
def extract_features(image_path, augment=False):
    with rasterio.open(image_path) as src:
        bands = src.read()

    feature_set = []
    band_sets = augment_image(bands) if augment else [(bands[3], bands[0], bands[1])]

    for nir, red, green in band_sets:
        # NDVI / NDWI
        ndvi = calculate_ndvi(nir, red)
        ndwi = calculate_ndwi(nir, green)

        # Feature vector
        features = [
            np.mean(ndvi), np.std(ndvi),
            np.mean(ndwi), np.std(ndwi),
            np.percentile(nir, 75),
            np.mean(green > np.quantile(green, 0.75))
        ]
        feature_set.append(features)

    return feature_set

# %% [markdown]
# >- load dataset with SMOTE

# %%
# Load dataset efficiently
train_dataset_path = Path('../../../../data/odm_dataset/Patches/Train')
test_dataset_path = Path('../../../../data/odm_dataset/Patches/Test/')
growth_stages = ["germination", "tillering", "grand_growth", "ripening"]
X, X_test, y, y_test = [], [], [], []

for idx, stage in enumerate(growth_stages):
    stage_path = train_dataset_path / stage
    for img_file in os.listdir(stage_path):
        img_path = stage_path / img_file
        feats = extract_features(img_path, augment=True)  # enable augmentation
        for f in feats:
            X.append(f)
            y.append(idx)

X = np.array(X)
y = np.array(y)

# ADD SMOTE
smote = SMOTE(random_state=42)
X_res, y_res = smote.fit_resample(X, y)

for idx, stage in enumerate(growth_stages):
    stage_path = test_dataset_path / stage
    for img_file in os.listdir(stage_path):
        img_path = stage_path / img_file
        feats = extract_features(img_path, augment=False)  # no augmentation
        for f in feats:   # usually only 1 feature vector
            X_test.append(f)
            y_test.append(idx)

X_test = np.array(X_test)
y_test = np.array(y_test)

# %% [markdown]
# >- setup model

# %%
# Define parameter grid for XGBoost
param_grid = {
    "n_estimators": [50, 100, 200],
    "max_depth": [3, 4, 6],
    "learning_rate": [0.005, 0.01, 0.1],
    "subsample": [0.6, 0.8, 1.0],
    "colsample_bytree": [0.8, 1.0],
    "reg_lambda": [0.0, 1.0],
    "reg_alpha": [0.0, 0.1]
}

# Initialize XGBoost and GridSearchCV
xgb_model = XGBClassifier(
    objective='multi:softmax',
    num_class=4,
    use_label_encoder=False, 
    eval_metric='mlogloss', 
    random_state=42
    )

kf = KFold(n_splits=2, shuffle=True, random_state=42)

grid_search = GridSearchCV(xgb_model, param_grid, cv=kf, n_jobs=-1, verbose=2, return_train_score=True)

# Train model with cross-validation
# grid_search.fit(X, y)
grid_search.fit(X_res, y_res)

# Get the best model from Grid Search
best_model = grid_search.best_estimator_

# Best parameters
print(f"Best Parameters: {grid_search.best_params_}")

# Train the model on the entire training dataset
history = best_model.fit(X_res, y_res, eval_set=[(X_res, y_res), (X_test, y_test)], verbose=True)

# Plot training and test accuracy
eval_results = best_model.evals_result()
train_accuracy = eval_results['validation_0']['mlogloss']
test_accuracy = eval_results['validation_1']['mlogloss']

plt.figure(figsize=(8, 6))
plt.plot(train_accuracy, label='Train Accuracy')
plt.plot(test_accuracy, label='Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Log Loss')
plt.title('Training vs Test Accuracy')
plt.legend()
plt.savefig(Path(os.path.join(output_img_dir, "ODM_XGB_V6_accuracy_plot.png")))
plt.show()
# Out:
# Fitting 2 folds for each of 648 candidates, totalling 1296 fits
# c:\Users\user\anaconda3\envs\research_env\lib\site-packages\xgboost\core.py:158: UserWarning: [19:33:59] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Best Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 200, 'reg_alpha': 0.0, 'reg_lambda': 0.0, 'subsample': 0.6}
# [0]	validation_0-mlogloss:1.27577	validation_1-mlogloss:1.29530
# [1]	validation_0-mlogloss:1.18297	validation_1-mlogloss:1.22118
# [2]	validation_0-mlogloss:1.10371	validation_1-mlogloss:1.15681
# [3]	validation_0-mlogloss:1.03543	validation_1-mlogloss:1.10366
# [4]	validation_0-mlogloss:0.97565	validation_1-mlogloss:1.05657
# [5]	validation_0-mlogloss:0.92330	validation_1-mlogloss:1.01435
# [6]	validation_0-mlogloss:0.87613	validation_1-mlogloss:0.97965
# [7]	validation_0-mlogloss:0.83317	validation_1-mlogloss:0.94857
# [8]	validation_0-mlogloss:0.79602	validation_1-mlogloss:0.92248
# [9]	validation_0-mlogloss:0.76115	validation_1-mlogloss:0.89675
# [10]	validation_0-mlogloss:0.72979	validation_1-mlogloss:0.87753
# [11]	validation_0-mlogloss:0.70141	validation_1-mlogloss:0.86025
# [12]	validation_0-mlogloss:0.67476	validation_1-mlogloss:0.84401
# [13]	validation_0-mlogloss:0.65246	validation_1-mlogloss:0.83067
# [14]	validation_0-mlogloss:0.63032	validation_1-mlogloss:0.81563
# [15]	validation_0-mlogloss:0.61046	validation_1-mlogloss:0.80314
# [16]	validation_0-mlogloss:0.59228	validation_1-mlogloss:0.79268
# [17]	validation_0-mlogloss:0.57379	validation_1-mlogloss:0.77953
# [18]	validation_0-mlogloss:0.55758	validation_1-mlogloss:0.76972
# c:\Users\user\anaconda3\envs\research_env\lib\site-packages\xgboost\core.py:158: UserWarning: [19:34:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [19]	validation_0-mlogloss:0.54212	validation_1-mlogloss:0.76253
# [20]	validation_0-mlogloss:0.52779	validation_1-mlogloss:0.75659
# [21]	validation_0-mlogloss:0.51446	validation_1-mlogloss:0.74925
# [22]	validation_0-mlogloss:0.50127	validation_1-mlogloss:0.74176
# [23]	validation_0-mlogloss:0.49026	validation_1-mlogloss:0.73489
# [24]	validation_0-mlogloss:0.47986	validation_1-mlogloss:0.72889
# [25]	validation_0-mlogloss:0.46863	validation_1-mlogloss:0.72291
# [26]	validation_0-mlogloss:0.45832	validation_1-mlogloss:0.71726
# [27]	validation_0-mlogloss:0.44904	validation_1-mlogloss:0.71270
# [28]	validation_0-mlogloss:0.44025	validation_1-mlogloss:0.70981
# [29]	validation_0-mlogloss:0.43199	validation_1-mlogloss:0.70712
# [30]	validation_0-mlogloss:0.42437	validation_1-mlogloss:0.70466
# [31]	validation_0-mlogloss:0.41706	validation_1-mlogloss:0.70127
# [32]	validation_0-mlogloss:0.40950	validation_1-mlogloss:0.69825
# [33]	validation_0-mlogloss:0.40243	validation_1-mlogloss:0.69474
# [34]	validation_0-mlogloss:0.39648	validation_1-mlogloss:0.69274
# [35]	validation_0-mlogloss:0.39045	validation_1-mlogloss:0.69001
# [36]	validation_0-mlogloss:0.38524	validation_1-mlogloss:0.68871
# [37]	validation_0-mlogloss:0.37950	validation_1-mlogloss:0.68577
# [38]	validation_0-mlogloss:0.37355	validation_1-mlogloss:0.68414
# [39]	validation_0-mlogloss:0.36801	validation_1-mlogloss:0.68202
# [40]	validation_0-mlogloss:0.36257	validation_1-mlogloss:0.67965
# [41]	validation_0-mlogloss:0.35815	validation_1-mlogloss:0.67864
# [42]	validation_0-mlogloss:0.35336	validation_1-mlogloss:0.67638
# [43]	validation_0-mlogloss:0.34876	validation_1-mlogloss:0.67482
# [44]	validation_0-mlogloss:0.34468	validation_1-mlogloss:0.67514
# [45]	validation_0-mlogloss:0.34069	validation_1-mlogloss:0.67344
# [46]	validation_0-mlogloss:0.33623	validation_1-mlogloss:0.67275
# [47]	validation_0-mlogloss:0.33211	validation_1-mlogloss:0.67268
# [48]	validation_0-mlogloss:0.32799	validation_1-mlogloss:0.67041
# [49]	validation_0-mlogloss:0.32468	validation_1-mlogloss:0.67038
# [50]	validation_0-mlogloss:0.32183	validation_1-mlogloss:0.67081
# [51]	validation_0-mlogloss:0.31794	validation_1-mlogloss:0.67067
# [52]	validation_0-mlogloss:0.31474	validation_1-mlogloss:0.66966
# [53]	validation_0-mlogloss:0.31121	validation_1-mlogloss:0.66922
# [54]	validation_0-mlogloss:0.30841	validation_1-mlogloss:0.67021
# [55]	validation_0-mlogloss:0.30508	validation_1-mlogloss:0.67090
# [56]	validation_0-mlogloss:0.30152	validation_1-mlogloss:0.67014
# [57]	validation_0-mlogloss:0.29878	validation_1-mlogloss:0.67021
# [58]	validation_0-mlogloss:0.29626	validation_1-mlogloss:0.67148
# [59]	validation_0-mlogloss:0.29353	validation_1-mlogloss:0.67199
# [60]	validation_0-mlogloss:0.29039	validation_1-mlogloss:0.67113
# [61]	validation_0-mlogloss:0.28717	validation_1-mlogloss:0.67219
# [62]	validation_0-mlogloss:0.28559	validation_1-mlogloss:0.67213
# [63]	validation_0-mlogloss:0.28317	validation_1-mlogloss:0.67293
# [64]	validation_0-mlogloss:0.28076	validation_1-mlogloss:0.67320
# [65]	validation_0-mlogloss:0.27766	validation_1-mlogloss:0.67312
# [66]	validation_0-mlogloss:0.27413	validation_1-mlogloss:0.67316
# [67]	validation_0-mlogloss:0.27118	validation_1-mlogloss:0.67262
# [68]	validation_0-mlogloss:0.26848	validation_1-mlogloss:0.67120
# [69]	validation_0-mlogloss:0.26645	validation_1-mlogloss:0.67020
# [70]	validation_0-mlogloss:0.26432	validation_1-mlogloss:0.66960
# [71]	validation_0-mlogloss:0.26264	validation_1-mlogloss:0.66932
# [72]	validation_0-mlogloss:0.26075	validation_1-mlogloss:0.67024
# [73]	validation_0-mlogloss:0.25811	validation_1-mlogloss:0.66993
# [74]	validation_0-mlogloss:0.25589	validation_1-mlogloss:0.67049
# [75]	validation_0-mlogloss:0.25367	validation_1-mlogloss:0.67126
# [76]	validation_0-mlogloss:0.25070	validation_1-mlogloss:0.67245
# [77]	validation_0-mlogloss:0.24757	validation_1-mlogloss:0.67184
# [78]	validation_0-mlogloss:0.24510	validation_1-mlogloss:0.67263
# [79]	validation_0-mlogloss:0.24282	validation_1-mlogloss:0.67356
# [80]	validation_0-mlogloss:0.24002	validation_1-mlogloss:0.67248
# [81]	validation_0-mlogloss:0.23811	validation_1-mlogloss:0.67269
# [82]	validation_0-mlogloss:0.23590	validation_1-mlogloss:0.67284
# [83]	validation_0-mlogloss:0.23337	validation_1-mlogloss:0.67366
# [84]	validation_0-mlogloss:0.23177	validation_1-mlogloss:0.67580
# [85]	validation_0-mlogloss:0.22911	validation_1-mlogloss:0.67778
# [86]	validation_0-mlogloss:0.22777	validation_1-mlogloss:0.67798
# [87]	validation_0-mlogloss:0.22619	validation_1-mlogloss:0.67746
# [88]	validation_0-mlogloss:0.22517	validation_1-mlogloss:0.67841
# [89]	validation_0-mlogloss:0.22315	validation_1-mlogloss:0.68001
# [90]	validation_0-mlogloss:0.22120	validation_1-mlogloss:0.67925
# [91]	validation_0-mlogloss:0.21986	validation_1-mlogloss:0.67921
# [92]	validation_0-mlogloss:0.21817	validation_1-mlogloss:0.67901
# [93]	validation_0-mlogloss:0.21676	validation_1-mlogloss:0.68057
# [94]	validation_0-mlogloss:0.21484	validation_1-mlogloss:0.68128
# [95]	validation_0-mlogloss:0.21366	validation_1-mlogloss:0.68181
# [96]	validation_0-mlogloss:0.21173	validation_1-mlogloss:0.68214
# [97]	validation_0-mlogloss:0.21039	validation_1-mlogloss:0.68364
# [98]	validation_0-mlogloss:0.20910	validation_1-mlogloss:0.68441
# [99]	validation_0-mlogloss:0.20787	validation_1-mlogloss:0.68505
# [100]	validation_0-mlogloss:0.20616	validation_1-mlogloss:0.68596
# [101]	validation_0-mlogloss:0.20398	validation_1-mlogloss:0.68561
# [102]	validation_0-mlogloss:0.20140	validation_1-mlogloss:0.68604
# [103]	validation_0-mlogloss:0.19941	validation_1-mlogloss:0.68604
# [104]	validation_0-mlogloss:0.19795	validation_1-mlogloss:0.68628
# [105]	validation_0-mlogloss:0.19583	validation_1-mlogloss:0.68739
# [106]	validation_0-mlogloss:0.19408	validation_1-mlogloss:0.68680
# [107]	validation_0-mlogloss:0.19335	validation_1-mlogloss:0.68710
# [108]	validation_0-mlogloss:0.19144	validation_1-mlogloss:0.68829
# [109]	validation_0-mlogloss:0.18956	validation_1-mlogloss:0.68975
# [110]	validation_0-mlogloss:0.18824	validation_1-mlogloss:0.69117
# [111]	validation_0-mlogloss:0.18663	validation_1-mlogloss:0.69152
# [112]	validation_0-mlogloss:0.18496	validation_1-mlogloss:0.69078
# [113]	validation_0-mlogloss:0.18310	validation_1-mlogloss:0.69177
# [114]	validation_0-mlogloss:0.18165	validation_1-mlogloss:0.69252
# [115]	validation_0-mlogloss:0.18069	validation_1-mlogloss:0.69221
# [116]	validation_0-mlogloss:0.18005	validation_1-mlogloss:0.69288
# [117]	validation_0-mlogloss:0.17868	validation_1-mlogloss:0.69316
# [118]	validation_0-mlogloss:0.17734	validation_1-mlogloss:0.69451
# [119]	validation_0-mlogloss:0.17609	validation_1-mlogloss:0.69483
# [120]	validation_0-mlogloss:0.17465	validation_1-mlogloss:0.69580
# [121]	validation_0-mlogloss:0.17332	validation_1-mlogloss:0.69480
# [122]	validation_0-mlogloss:0.17218	validation_1-mlogloss:0.69539
# [123]	validation_0-mlogloss:0.17078	validation_1-mlogloss:0.69638
# [124]	validation_0-mlogloss:0.16957	validation_1-mlogloss:0.69668
# [125]	validation_0-mlogloss:0.16822	validation_1-mlogloss:0.69684
# [126]	validation_0-mlogloss:0.16710	validation_1-mlogloss:0.69624
# [127]	validation_0-mlogloss:0.16584	validation_1-mlogloss:0.69730
# [128]	validation_0-mlogloss:0.16457	validation_1-mlogloss:0.69768
# [129]	validation_0-mlogloss:0.16379	validation_1-mlogloss:0.69798
# [130]	validation_0-mlogloss:0.16266	validation_1-mlogloss:0.69676
# [131]	validation_0-mlogloss:0.16139	validation_1-mlogloss:0.69666
# [132]	validation_0-mlogloss:0.16031	validation_1-mlogloss:0.69732
# [133]	validation_0-mlogloss:0.15942	validation_1-mlogloss:0.69830
# [134]	validation_0-mlogloss:0.15844	validation_1-mlogloss:0.69871
# [135]	validation_0-mlogloss:0.15738	validation_1-mlogloss:0.69913
# [136]	validation_0-mlogloss:0.15603	validation_1-mlogloss:0.69949
# [137]	validation_0-mlogloss:0.15505	validation_1-mlogloss:0.70155
# [138]	validation_0-mlogloss:0.15413	validation_1-mlogloss:0.70155
# [139]	validation_0-mlogloss:0.15280	validation_1-mlogloss:0.70234
# [140]	validation_0-mlogloss:0.15189	validation_1-mlogloss:0.70382
# [141]	validation_0-mlogloss:0.15099	validation_1-mlogloss:0.70539
# [142]	validation_0-mlogloss:0.14943	validation_1-mlogloss:0.70528
# [143]	validation_0-mlogloss:0.14864	validation_1-mlogloss:0.70639
# [144]	validation_0-mlogloss:0.14764	validation_1-mlogloss:0.70809
# [145]	validation_0-mlogloss:0.14634	validation_1-mlogloss:0.70865
# [146]	validation_0-mlogloss:0.14511	validation_1-mlogloss:0.70952
# [147]	validation_0-mlogloss:0.14423	validation_1-mlogloss:0.71050
# [148]	validation_0-mlogloss:0.14310	validation_1-mlogloss:0.71071
# [149]	validation_0-mlogloss:0.14227	validation_1-mlogloss:0.71125
# [150]	validation_0-mlogloss:0.14097	validation_1-mlogloss:0.71095
# [151]	validation_0-mlogloss:0.13974	validation_1-mlogloss:0.71199
# [152]	validation_0-mlogloss:0.13884	validation_1-mlogloss:0.71258
# [153]	validation_0-mlogloss:0.13819	validation_1-mlogloss:0.71366
# [154]	validation_0-mlogloss:0.13729	validation_1-mlogloss:0.71463
# [155]	validation_0-mlogloss:0.13643	validation_1-mlogloss:0.71550
# [156]	validation_0-mlogloss:0.13554	validation_1-mlogloss:0.71589
# [157]	validation_0-mlogloss:0.13415	validation_1-mlogloss:0.71590
# [158]	validation_0-mlogloss:0.13307	validation_1-mlogloss:0.71708
# [159]	validation_0-mlogloss:0.13209	validation_1-mlogloss:0.71772
# [160]	validation_0-mlogloss:0.13153	validation_1-mlogloss:0.71832
# [161]	validation_0-mlogloss:0.13066	validation_1-mlogloss:0.71836
# [162]	validation_0-mlogloss:0.13008	validation_1-mlogloss:0.71937
# [163]	validation_0-mlogloss:0.12920	validation_1-mlogloss:0.71955
# [164]	validation_0-mlogloss:0.12862	validation_1-mlogloss:0.72119
# [165]	validation_0-mlogloss:0.12795	validation_1-mlogloss:0.72221
# [166]	validation_0-mlogloss:0.12696	validation_1-mlogloss:0.72281
# [167]	validation_0-mlogloss:0.12631	validation_1-mlogloss:0.72338
# [168]	validation_0-mlogloss:0.12577	validation_1-mlogloss:0.72379
# [169]	validation_0-mlogloss:0.12518	validation_1-mlogloss:0.72484
# [170]	validation_0-mlogloss:0.12399	validation_1-mlogloss:0.72530
# [171]	validation_0-mlogloss:0.12300	validation_1-mlogloss:0.72631
# [172]	validation_0-mlogloss:0.12222	validation_1-mlogloss:0.72713
# [173]	validation_0-mlogloss:0.12142	validation_1-mlogloss:0.72654
# [174]	validation_0-mlogloss:0.12043	validation_1-mlogloss:0.72773
# [175]	validation_0-mlogloss:0.11972	validation_1-mlogloss:0.72816
# [176]	validation_0-mlogloss:0.11895	validation_1-mlogloss:0.72868
# [177]	validation_0-mlogloss:0.11827	validation_1-mlogloss:0.72911
# [178]	validation_0-mlogloss:0.11753	validation_1-mlogloss:0.73015
# [179]	validation_0-mlogloss:0.11656	validation_1-mlogloss:0.73125
# [180]	validation_0-mlogloss:0.11592	validation_1-mlogloss:0.73143
# [181]	validation_0-mlogloss:0.11522	validation_1-mlogloss:0.73311
# [182]	validation_0-mlogloss:0.11480	validation_1-mlogloss:0.73330
# [183]	validation_0-mlogloss:0.11401	validation_1-mlogloss:0.73415
# [184]	validation_0-mlogloss:0.11311	validation_1-mlogloss:0.73439
# [185]	validation_0-mlogloss:0.11260	validation_1-mlogloss:0.73476
# [186]	validation_0-mlogloss:0.11212	validation_1-mlogloss:0.73542
# [187]	validation_0-mlogloss:0.11147	validation_1-mlogloss:0.73676
# [188]	validation_0-mlogloss:0.11065	validation_1-mlogloss:0.73703
# [189]	validation_0-mlogloss:0.11004	validation_1-mlogloss:0.73674
# [190]	validation_0-mlogloss:0.10923	validation_1-mlogloss:0.73827
# [191]	validation_0-mlogloss:0.10871	validation_1-mlogloss:0.73937
# [192]	validation_0-mlogloss:0.10802	validation_1-mlogloss:0.73980
# [193]	validation_0-mlogloss:0.10750	validation_1-mlogloss:0.74084
# [194]	validation_0-mlogloss:0.10659	validation_1-mlogloss:0.74129
# [195]	validation_0-mlogloss:0.10597	validation_1-mlogloss:0.74133
# [196]	validation_0-mlogloss:0.10510	validation_1-mlogloss:0.74345
# [197]	validation_0-mlogloss:0.10456	validation_1-mlogloss:0.74509
# [198]	validation_0-mlogloss:0.10407	validation_1-mlogloss:0.74522
# [199]	validation_0-mlogloss:0.10335	validation_1-mlogloss:0.74599

# %% [markdown]
# >- evaluate model

# %%
# Evaluate the model on the test set
y_test_pred = best_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_test_pred)
test_report = classification_report(y_test, y_test_pred)

# Calculate additional metrics
test_precision = precision_score(y_test, y_test_pred, average='weighted')
test_recall = recall_score(y_test, y_test_pred, average='weighted')
test_f1 = f1_score(y_test, y_test_pred, average='weighted')
confusion = confusion_matrix(y_test, y_test_pred)

# Log confusion matrix as an image
plt.figure(figsize=(8, 6))
sns.heatmap(confusion, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.savefig(Path(os.path.join(output_img_dir, "ODM_XGB_V6_confusion_matrix.png"))) # Save confusion matrix

# Print results
print(f"Test Accuracy: {test_accuracy}")
print(f"Test Precision: {test_precision}")
print(f"Test Recall: {test_recall}")
print(f"Test F1 Score: {test_f1}")
print(f"Classification Report:\n{test_report}")

# Save the best model to disk
XGB_model_v5 = Path(os.path.join(output_model_dir, "XGB_model_v6.joblib"))
joblib.dump(best_model, XGB_model_v5)
print(f"Saved model to: {XGB_model_v5}")

# Evaluate using cross-validation accuracy
print(f"Best Cross-Validation Accuracy: {grid_search.best_score_ * 100:.2f}%")
# Out:
# Test Accuracy: 0.7086092715231788
# Test Precision: 0.7100958048135658
# Test Recall: 0.7086092715231788
# Test F1 Score: 0.7062417337063099
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.69      0.72      0.70        97
#            1       0.68      0.55      0.60        77
#            2       0.65      0.78      0.71        51
#            3       0.82      0.81      0.81        77
#
#     accuracy                           0.71       302
#    macro avg       0.71      0.71      0.71       302
# weighted avg       0.71      0.71      0.71       302
#
# Saved model to: ..\output\XGBoost\model\XGB_model_v6.joblib
# Best Cross-Validation Accuracy: 93.50%

# %% [markdown]
# >- predict

# %%
# Load the best model
model = joblib.load(Path(XGB_model_v5))

def predict_growth_stage(image_path, model):
    # Get features without augmentation
    feats = extract_features(image_path, augment=False)

    # feats is a list, but contains only 1 element when augment=False
    features = feats[0]

    # Predict
    predicted_label = model.predict([features])[0]
    return growth_stages[predicted_label]

new_image = Path('../../../../data/odm_dataset/Patches/Train/tillering/patch_92.tif')
predicted_stage = predict_growth_stage(new_image, model)
print(f"Predicted Growth Stage: {predicted_stage}")
print()
# Out:
# Predicted Growth Stage: tillering
