# %% [markdown]
# ## XGBoost modifications
#  - V1 : Use SMOTE --> with new dataset

# %% [markdown]
# >- import packages

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import rasterio
from sklearn.model_selection import KFold, GridSearchCV
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report, f1_score, precision_score, recall_score, confusion_matrix
import joblib 
from pathlib import Path

# for data leveling
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline

# %% [markdown]
# >- Define function & modify

# %%
# define ouput dir
output_dir = Path("../output/XGBoost")
output_dir.mkdir(parents=True, exist_ok=True)

output_img_dir = output_dir / "IMG"
output_img_dir.mkdir(parents=True, exist_ok=True)

output_model_dir = output_dir / "model"
output_model_dir.mkdir(parents=True, exist_ok=True)

# %%
# Define functions to calculate NDVI and NDWI
def calculate_ndvi(nir, red):
    return (nir - red) / (nir + red + 1e-10)

def calculate_ndwi(nir, green):
    return (nir - green) / (nir + green + 1e-10)

'''
    Enhanced Feature Engineering:
        -  Current features (mean NDVI/NDWI) might be insufficient. Add:

'''
def extract_features(image_path):
    with rasterio.open(image_path) as src:
        bands = src.read()
        nir, red, green = bands[3], bands[0], bands[1]
        
        # Existing features
        ndvi = calculate_ndvi(nir, red)
        ndwi = calculate_ndwi(nir, green)
        
        # New features
        return [
            np.mean(ndvi), np.std(ndvi),  # Add standard deviation
            np.mean(ndwi), np.std(ndwi),
            np.percentile(nir, 75),  # Texture features
            np.mean(green > np.quantile(green, 0.75))  # Threshold features
        ]

# %% [markdown]
# >- load dataset with SMOTE

# %%
# Load dataset efficiently
train_dataset_path = Path('../../../../data/odm_dataset/Patches/Train')
test_dataset_path = Path('../../../../data/odm_dataset/Patches/Test/')
growth_stages = ["germination", "tillering", "grand_growth", "ripening"]
X, X_test, y, y_test = [], [], [], []

for idx, stage in enumerate(growth_stages):
    stage_path = train_dataset_path / stage
    for img_file in os.listdir(stage_path):
        img_path = stage_path / img_file
        X.append(extract_features(img_path))
        y.append(idx)

X = np.array(X)
y = np.array(y)

# ADD SMOTE
smote = SMOTE(random_state=42)
X_res, y_res = smote.fit_resample(X, y)

for idx, stage in enumerate(growth_stages):
    stage_path = test_dataset_path / stage
    for img_file in os.listdir(stage_path):
        img_path = stage_path / img_file
        X_test.append(extract_features(img_path))
        y_test.append(idx)

X_test = np.array(X_test)
y_test = np.array(y_test)

# %% [markdown]
# >- setup model

# %%
# Define parameter grid for XGBoost
param_grid = {
    "n_estimators": [50, 100, 200],
    "max_depth": [3, 6, 10],
    "learning_rate": [0.01, 0.1, 0.2],
    "subsample": [0.8, 1.0],
    "colsample_bytree": [0.8, 1.0]
}

# Initialize XGBoost and GridSearchCV
xgb_model = XGBClassifier(
    objective='multi:softmax',
    num_class=4,
    use_label_encoder=False, 
    eval_metric='mlogloss', 
    random_state=42
    )

kf = KFold(n_splits=5, shuffle=True, random_state=42)

grid_search = GridSearchCV(xgb_model, param_grid, cv=kf, n_jobs=-1, verbose=2, return_train_score=True)

# Train model with cross-validation
# grid_search.fit(X, y)
grid_search.fit(X_res, y_res)

# Get the best model from Grid Search
best_model = grid_search.best_estimator_

# Best parameters
print(f"Best Parameters: {grid_search.best_params_}")

# Train the model on the entire training dataset
history = best_model.fit(X_res, y_res, eval_set=[(X_res, y_res), (X_test, y_test)], verbose=True)


# Plot training and test accuracy
eval_results = best_model.evals_result()
train_accuracy = eval_results['validation_0']['mlogloss']
test_accuracy = eval_results['validation_1']['mlogloss']

plt.figure(figsize=(8, 6))
plt.plot(train_accuracy, label='Train Accuracy')
plt.plot(test_accuracy, label='Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Log Loss')
plt.title('Training vs Test Accuracy')
plt.legend()
plt.savefig(Path(os.path.join(output_img_dir, "ODM_XGB_V12_accuracy_plot.png")))
plt.show()
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# c:\Users\user\anaconda3\envs\research_env\lib\site-packages\xgboost\core.py:158: UserWarning: [18:40:24] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Best Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 200, 'subsample': 0.8}
# [0]	validation_0-mlogloss:1.22381	validation_1-mlogloss:1.23070
# [1]	validation_0-mlogloss:1.09149	validation_1-mlogloss:1.10426
# [2]	validation_0-mlogloss:0.98129	validation_1-mlogloss:0.99946
# [3]	validation_0-mlogloss:0.88773	validation_1-mlogloss:0.91075
# [4]	validation_0-mlogloss:0.80688	validation_1-mlogloss:0.83440
# [5]	validation_0-mlogloss:0.73658	validation_1-mlogloss:0.76804
# c:\Users\user\anaconda3\envs\research_env\lib\site-packages\xgboost\core.py:158: UserWarning: [18:40:27] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [6]	validation_0-mlogloss:0.67493	validation_1-mlogloss:0.71017
# [7]	validation_0-mlogloss:0.62070	validation_1-mlogloss:0.65932
# [8]	validation_0-mlogloss:0.57278	validation_1-mlogloss:0.61481
# [9]	validation_0-mlogloss:0.53026	validation_1-mlogloss:0.57548
# [10]	validation_0-mlogloss:0.49227	validation_1-mlogloss:0.54055
# [11]	validation_0-mlogloss:0.45818	validation_1-mlogloss:0.50932
# [12]	validation_0-mlogloss:0.42758	validation_1-mlogloss:0.48148
# [13]	validation_0-mlogloss:0.40011	validation_1-mlogloss:0.45656
# [14]	validation_0-mlogloss:0.37550	validation_1-mlogloss:0.43425
# [15]	validation_0-mlogloss:0.35319	validation_1-mlogloss:0.41398
# [16]	validation_0-mlogloss:0.33296	validation_1-mlogloss:0.39610
# [17]	validation_0-mlogloss:0.31465	validation_1-mlogloss:0.38004
# [18]	validation_0-mlogloss:0.29834	validation_1-mlogloss:0.36573
# [19]	validation_0-mlogloss:0.28348	validation_1-mlogloss:0.35278
# [20]	validation_0-mlogloss:0.26989	validation_1-mlogloss:0.34112
# [21]	validation_0-mlogloss:0.25742	validation_1-mlogloss:0.33040
# [22]	validation_0-mlogloss:0.24582	validation_1-mlogloss:0.32061
# [23]	validation_0-mlogloss:0.23554	validation_1-mlogloss:0.31196
# [24]	validation_0-mlogloss:0.22609	validation_1-mlogloss:0.30420
# [25]	validation_0-mlogloss:0.21721	validation_1-mlogloss:0.29699
# [26]	validation_0-mlogloss:0.20904	validation_1-mlogloss:0.29049
# [27]	validation_0-mlogloss:0.20180	validation_1-mlogloss:0.28489
# [28]	validation_0-mlogloss:0.19509	validation_1-mlogloss:0.27958
# [29]	validation_0-mlogloss:0.18862	validation_1-mlogloss:0.27463
# [30]	validation_0-mlogloss:0.18289	validation_1-mlogloss:0.27043
# [31]	validation_0-mlogloss:0.17770	validation_1-mlogloss:0.26658
# [32]	validation_0-mlogloss:0.17290	validation_1-mlogloss:0.26286
# [33]	validation_0-mlogloss:0.16854	validation_1-mlogloss:0.25948
# [34]	validation_0-mlogloss:0.16424	validation_1-mlogloss:0.25624
# [35]	validation_0-mlogloss:0.16030	validation_1-mlogloss:0.25336
# [36]	validation_0-mlogloss:0.15675	validation_1-mlogloss:0.25077
# [37]	validation_0-mlogloss:0.15335	validation_1-mlogloss:0.24834
# [38]	validation_0-mlogloss:0.15000	validation_1-mlogloss:0.24594
# [39]	validation_0-mlogloss:0.14719	validation_1-mlogloss:0.24394
# [40]	validation_0-mlogloss:0.14435	validation_1-mlogloss:0.24197
# [41]	validation_0-mlogloss:0.14179	validation_1-mlogloss:0.24030
# [42]	validation_0-mlogloss:0.13941	validation_1-mlogloss:0.23865
# [43]	validation_0-mlogloss:0.13728	validation_1-mlogloss:0.23719
# [44]	validation_0-mlogloss:0.13523	validation_1-mlogloss:0.23610
# [45]	validation_0-mlogloss:0.13344	validation_1-mlogloss:0.23477
# [46]	validation_0-mlogloss:0.13173	validation_1-mlogloss:0.23383
# [47]	validation_0-mlogloss:0.13023	validation_1-mlogloss:0.23292
# [48]	validation_0-mlogloss:0.12876	validation_1-mlogloss:0.23191
# [49]	validation_0-mlogloss:0.12741	validation_1-mlogloss:0.23091
# [50]	validation_0-mlogloss:0.12611	validation_1-mlogloss:0.23019
# [51]	validation_0-mlogloss:0.12473	validation_1-mlogloss:0.22930
# [52]	validation_0-mlogloss:0.12339	validation_1-mlogloss:0.22857
# [53]	validation_0-mlogloss:0.12221	validation_1-mlogloss:0.22789
# [54]	validation_0-mlogloss:0.12096	validation_1-mlogloss:0.22735
# [55]	validation_0-mlogloss:0.11983	validation_1-mlogloss:0.22683
# [56]	validation_0-mlogloss:0.11862	validation_1-mlogloss:0.22639
# [57]	validation_0-mlogloss:0.11774	validation_1-mlogloss:0.22594
# [58]	validation_0-mlogloss:0.11675	validation_1-mlogloss:0.22542
# [59]	validation_0-mlogloss:0.11559	validation_1-mlogloss:0.22504
# [60]	validation_0-mlogloss:0.11463	validation_1-mlogloss:0.22465
# [61]	validation_0-mlogloss:0.11392	validation_1-mlogloss:0.22419
# [62]	validation_0-mlogloss:0.11297	validation_1-mlogloss:0.22395
# [63]	validation_0-mlogloss:0.11236	validation_1-mlogloss:0.22358
# [64]	validation_0-mlogloss:0.11148	validation_1-mlogloss:0.22316
# [65]	validation_0-mlogloss:0.11045	validation_1-mlogloss:0.22278
# [66]	validation_0-mlogloss:0.10974	validation_1-mlogloss:0.22254
# [67]	validation_0-mlogloss:0.10871	validation_1-mlogloss:0.22249
# [68]	validation_0-mlogloss:0.10777	validation_1-mlogloss:0.22217
# [69]	validation_0-mlogloss:0.10701	validation_1-mlogloss:0.22183
# [70]	validation_0-mlogloss:0.10612	validation_1-mlogloss:0.22167
# [71]	validation_0-mlogloss:0.10534	validation_1-mlogloss:0.22152
# [72]	validation_0-mlogloss:0.10457	validation_1-mlogloss:0.22129
# [73]	validation_0-mlogloss:0.10371	validation_1-mlogloss:0.22110
# [74]	validation_0-mlogloss:0.10300	validation_1-mlogloss:0.22088
# [75]	validation_0-mlogloss:0.10210	validation_1-mlogloss:0.22077
# [76]	validation_0-mlogloss:0.10137	validation_1-mlogloss:0.22061
# [77]	validation_0-mlogloss:0.10067	validation_1-mlogloss:0.22053
# [78]	validation_0-mlogloss:0.09980	validation_1-mlogloss:0.22040
# [79]	validation_0-mlogloss:0.09923	validation_1-mlogloss:0.22025
# [80]	validation_0-mlogloss:0.09856	validation_1-mlogloss:0.22014
# [81]	validation_0-mlogloss:0.09799	validation_1-mlogloss:0.22005
# [82]	validation_0-mlogloss:0.09713	validation_1-mlogloss:0.22005
# [83]	validation_0-mlogloss:0.09651	validation_1-mlogloss:0.21995
# [84]	validation_0-mlogloss:0.09569	validation_1-mlogloss:0.21978
# [85]	validation_0-mlogloss:0.09487	validation_1-mlogloss:0.21962
# [86]	validation_0-mlogloss:0.09421	validation_1-mlogloss:0.21940
# [87]	validation_0-mlogloss:0.09346	validation_1-mlogloss:0.21911
# [88]	validation_0-mlogloss:0.09287	validation_1-mlogloss:0.21891
# [89]	validation_0-mlogloss:0.09215	validation_1-mlogloss:0.21888
# [90]	validation_0-mlogloss:0.09137	validation_1-mlogloss:0.21890
# [91]	validation_0-mlogloss:0.09064	validation_1-mlogloss:0.21891
# [92]	validation_0-mlogloss:0.08988	validation_1-mlogloss:0.21893
# [93]	validation_0-mlogloss:0.08933	validation_1-mlogloss:0.21899
# [94]	validation_0-mlogloss:0.08860	validation_1-mlogloss:0.21902
# [95]	validation_0-mlogloss:0.08755	validation_1-mlogloss:0.21920
# [96]	validation_0-mlogloss:0.08698	validation_1-mlogloss:0.21930
# [97]	validation_0-mlogloss:0.08635	validation_1-mlogloss:0.21932
# [98]	validation_0-mlogloss:0.08557	validation_1-mlogloss:0.21924
# [99]	validation_0-mlogloss:0.08489	validation_1-mlogloss:0.21925
# [100]	validation_0-mlogloss:0.08441	validation_1-mlogloss:0.21929
# [101]	validation_0-mlogloss:0.08376	validation_1-mlogloss:0.21923
# [102]	validation_0-mlogloss:0.08312	validation_1-mlogloss:0.21923
# [103]	validation_0-mlogloss:0.08243	validation_1-mlogloss:0.21948
# [104]	validation_0-mlogloss:0.08165	validation_1-mlogloss:0.21950
# [105]	validation_0-mlogloss:0.08102	validation_1-mlogloss:0.21957
# [106]	validation_0-mlogloss:0.08023	validation_1-mlogloss:0.21984
# [107]	validation_0-mlogloss:0.07966	validation_1-mlogloss:0.21994
# [108]	validation_0-mlogloss:0.07919	validation_1-mlogloss:0.21990
# [109]	validation_0-mlogloss:0.07859	validation_1-mlogloss:0.22002
# [110]	validation_0-mlogloss:0.07813	validation_1-mlogloss:0.22001
# [111]	validation_0-mlogloss:0.07761	validation_1-mlogloss:0.22009
# [112]	validation_0-mlogloss:0.07700	validation_1-mlogloss:0.22020
# [113]	validation_0-mlogloss:0.07633	validation_1-mlogloss:0.22040
# [114]	validation_0-mlogloss:0.07581	validation_1-mlogloss:0.22051
# [115]	validation_0-mlogloss:0.07518	validation_1-mlogloss:0.22067
# [116]	validation_0-mlogloss:0.07464	validation_1-mlogloss:0.22071
# [117]	validation_0-mlogloss:0.07401	validation_1-mlogloss:0.22086
# [118]	validation_0-mlogloss:0.07339	validation_1-mlogloss:0.22107
# [119]	validation_0-mlogloss:0.07246	validation_1-mlogloss:0.22122
# [120]	validation_0-mlogloss:0.07180	validation_1-mlogloss:0.22121
# [121]	validation_0-mlogloss:0.07111	validation_1-mlogloss:0.22122
# [122]	validation_0-mlogloss:0.07048	validation_1-mlogloss:0.22154
# [123]	validation_0-mlogloss:0.06971	validation_1-mlogloss:0.22164
# [124]	validation_0-mlogloss:0.06905	validation_1-mlogloss:0.22170
# [125]	validation_0-mlogloss:0.06842	validation_1-mlogloss:0.22169
# [126]	validation_0-mlogloss:0.06779	validation_1-mlogloss:0.22176
# [127]	validation_0-mlogloss:0.06732	validation_1-mlogloss:0.22191
# [128]	validation_0-mlogloss:0.06689	validation_1-mlogloss:0.22201
# [129]	validation_0-mlogloss:0.06650	validation_1-mlogloss:0.22212
# [130]	validation_0-mlogloss:0.06581	validation_1-mlogloss:0.22228
# [131]	validation_0-mlogloss:0.06522	validation_1-mlogloss:0.22246
# [132]	validation_0-mlogloss:0.06473	validation_1-mlogloss:0.22265
# [133]	validation_0-mlogloss:0.06420	validation_1-mlogloss:0.22277
# [134]	validation_0-mlogloss:0.06373	validation_1-mlogloss:0.22276
# [135]	validation_0-mlogloss:0.06311	validation_1-mlogloss:0.22281
# [136]	validation_0-mlogloss:0.06259	validation_1-mlogloss:0.22295
# [137]	validation_0-mlogloss:0.06185	validation_1-mlogloss:0.22329
# [138]	validation_0-mlogloss:0.06133	validation_1-mlogloss:0.22337
# [139]	validation_0-mlogloss:0.06091	validation_1-mlogloss:0.22350
# [140]	validation_0-mlogloss:0.06030	validation_1-mlogloss:0.22360
# [141]	validation_0-mlogloss:0.05978	validation_1-mlogloss:0.22387
# [142]	validation_0-mlogloss:0.05949	validation_1-mlogloss:0.22388
# [143]	validation_0-mlogloss:0.05906	validation_1-mlogloss:0.22400
# [144]	validation_0-mlogloss:0.05854	validation_1-mlogloss:0.22423
# [145]	validation_0-mlogloss:0.05805	validation_1-mlogloss:0.22429
# [146]	validation_0-mlogloss:0.05763	validation_1-mlogloss:0.22445
# [147]	validation_0-mlogloss:0.05720	validation_1-mlogloss:0.22456
# [148]	validation_0-mlogloss:0.05686	validation_1-mlogloss:0.22468
# [149]	validation_0-mlogloss:0.05639	validation_1-mlogloss:0.22483
# [150]	validation_0-mlogloss:0.05599	validation_1-mlogloss:0.22505
# [151]	validation_0-mlogloss:0.05567	validation_1-mlogloss:0.22524
# [152]	validation_0-mlogloss:0.05510	validation_1-mlogloss:0.22549
# [153]	validation_0-mlogloss:0.05466	validation_1-mlogloss:0.22567
# [154]	validation_0-mlogloss:0.05419	validation_1-mlogloss:0.22591
# [155]	validation_0-mlogloss:0.05378	validation_1-mlogloss:0.22588
# [156]	validation_0-mlogloss:0.05347	validation_1-mlogloss:0.22595
# [157]	validation_0-mlogloss:0.05314	validation_1-mlogloss:0.22604
# [158]	validation_0-mlogloss:0.05279	validation_1-mlogloss:0.22616
# [159]	validation_0-mlogloss:0.05246	validation_1-mlogloss:0.22633
# [160]	validation_0-mlogloss:0.05207	validation_1-mlogloss:0.22662
# [161]	validation_0-mlogloss:0.05164	validation_1-mlogloss:0.22677
# [162]	validation_0-mlogloss:0.05125	validation_1-mlogloss:0.22690
# [163]	validation_0-mlogloss:0.05089	validation_1-mlogloss:0.22699
# [164]	validation_0-mlogloss:0.05056	validation_1-mlogloss:0.22713
# [165]	validation_0-mlogloss:0.05016	validation_1-mlogloss:0.22742
# [166]	validation_0-mlogloss:0.04969	validation_1-mlogloss:0.22774
# [167]	validation_0-mlogloss:0.04936	validation_1-mlogloss:0.22785
# [168]	validation_0-mlogloss:0.04904	validation_1-mlogloss:0.22788
# [169]	validation_0-mlogloss:0.04867	validation_1-mlogloss:0.22810
# [170]	validation_0-mlogloss:0.04842	validation_1-mlogloss:0.22812
# [171]	validation_0-mlogloss:0.04784	validation_1-mlogloss:0.22830
# [172]	validation_0-mlogloss:0.04747	validation_1-mlogloss:0.22850
# [173]	validation_0-mlogloss:0.04711	validation_1-mlogloss:0.22872
# [174]	validation_0-mlogloss:0.04674	validation_1-mlogloss:0.22892
# [175]	validation_0-mlogloss:0.04650	validation_1-mlogloss:0.22903
# [176]	validation_0-mlogloss:0.04613	validation_1-mlogloss:0.22925
# [177]	validation_0-mlogloss:0.04587	validation_1-mlogloss:0.22943
# [178]	validation_0-mlogloss:0.04555	validation_1-mlogloss:0.22970
# [179]	validation_0-mlogloss:0.04520	validation_1-mlogloss:0.22980
# [180]	validation_0-mlogloss:0.04494	validation_1-mlogloss:0.22990
# [181]	validation_0-mlogloss:0.04463	validation_1-mlogloss:0.22997
# [182]	validation_0-mlogloss:0.04428	validation_1-mlogloss:0.23015
# [183]	validation_0-mlogloss:0.04395	validation_1-mlogloss:0.23037
# [184]	validation_0-mlogloss:0.04379	validation_1-mlogloss:0.23045
# [185]	validation_0-mlogloss:0.04354	validation_1-mlogloss:0.23055
# [186]	validation_0-mlogloss:0.04321	validation_1-mlogloss:0.23085
# [187]	validation_0-mlogloss:0.04298	validation_1-mlogloss:0.23098
# [188]	validation_0-mlogloss:0.04283	validation_1-mlogloss:0.23109
# [189]	validation_0-mlogloss:0.04260	validation_1-mlogloss:0.23122
# [190]	validation_0-mlogloss:0.04227	validation_1-mlogloss:0.23152
# [191]	validation_0-mlogloss:0.04205	validation_1-mlogloss:0.23176
# [192]	validation_0-mlogloss:0.04161	validation_1-mlogloss:0.23192
# [193]	validation_0-mlogloss:0.04128	validation_1-mlogloss:0.23235
# [194]	validation_0-mlogloss:0.04092	validation_1-mlogloss:0.23257
# [195]	validation_0-mlogloss:0.04066	validation_1-mlogloss:0.23273
# [196]	validation_0-mlogloss:0.04043	validation_1-mlogloss:0.23291
# [197]	validation_0-mlogloss:0.04011	validation_1-mlogloss:0.23304
# [198]	validation_0-mlogloss:0.03993	validation_1-mlogloss:0.23318
# [199]	validation_0-mlogloss:0.03971	validation_1-mlogloss:0.23349

# %% [markdown]
# >- evaluate model

# %%
# Evaluate the model on the test set
y_test_pred = best_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_test_pred)
test_report = classification_report(y_test, y_test_pred)

# Calculate additional metrics
test_precision = precision_score(y_test, y_test_pred, average='weighted')
test_recall = recall_score(y_test, y_test_pred, average='weighted')
test_f1 = f1_score(y_test, y_test_pred, average='weighted')
confusion = confusion_matrix(y_test, y_test_pred)

# Log confusion matrix as an image
plt.figure(figsize=(8, 6))
sns.heatmap(confusion, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.savefig(Path(os.path.join(output_img_dir, "ODM_XGB_V12_confusion_matrix.png"))) # Save confusion matrix

# Print results
print(f"Test Accuracy: {test_accuracy}")
print(f"Test Precision: {test_precision}")
print(f"Test Recall: {test_recall}")
print(f"Test F1 Score: {test_f1}")
print(f"Classification Report:\n{test_report}")

# Save the best model to disk
XGB_model_v12 = Path(os.path.join(output_model_dir, "XGB_model_v13.joblib"))
joblib.dump(best_model, XGB_model_v12)
print(f"Saved model to: {XGB_model_v12}")

# Evaluate using cross-validation accuracy
print(f"Best Cross-Validation Accuracy: {grid_search.best_score_ * 100:.2f}%")
# Out:
# Test Accuracy: 0.9123711340206185
# Test Precision: 0.9134965810320494
# Test Recall: 0.9123711340206185
# Test F1 Score: 0.9127094690553648
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.91      0.92      2618
#            1       0.90      0.89      0.89      2022
#            2       0.95      0.94      0.95      2495
#            3       0.82      0.90      0.86       819
#
#     accuracy                           0.91      7954
#    macro avg       0.90      0.91      0.90      7954
# weighted avg       0.91      0.91      0.91      7954
#
# Saved model to: ..\output\XGBoost\model\XGB_model_v13.joblib
# Best Cross-Validation Accuracy: 93.22%

# %% [markdown]
# >- predict

# %%
# Load the best model
# model = joblib.load(Path(XGB_model_v12))
model = best_model

def predict_growth_stage(image_path, model):
    features = extract_features(image_path)
    predicted_label = model.predict([features])[0]
    return growth_stages[predicted_label]

new_image = Path('../../../../data/odm_dataset/Patches/Test/ripening/patch_238.tif')
predicted_stage = predict_growth_stage(new_image, model)
print(f"Predicted Growth Stage: {predicted_stage}")
print()
# Out:
# Predicted Growth Stage: ripening
