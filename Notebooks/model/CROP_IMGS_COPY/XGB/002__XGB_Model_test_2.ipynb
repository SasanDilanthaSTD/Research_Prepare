# %% [markdown]
# ### Import packeges

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import rasterio
from sklearn.model_selection import KFold, GridSearchCV
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report, f1_score, precision_score, recall_score, confusion_matrix
import joblib 
from pathlib import Path

# %%
# Define functions to calculate NDVI and NDWI
def calculate_ndvi(nir, red):
    return (nir - red) / (nir + red + 1e-10)

def calculate_ndwi(nir, green):
    return (nir - green) / (nir + green + 1e-10)

# Function to extract mean NDVI & NDWI as features
def extract_features(image_path):
    with rasterio.open(image_path) as src:
        bands = src.read()
        nir, red, green = bands[4], bands[2], bands[1]  # Adjust based on band order
        
        ndvi = calculate_ndvi(nir, red)
        ndwi = calculate_ndwi(nir, green)

        return [np.mean(ndvi), np.mean(ndwi)]  # Use mean as feature

# %%
growth_stages = ["germination", "tillering", "grand_growth", "ripening"]

# %%
# Load dataset efficiently
train_dataset_path = Path('../../../../data/model/Patches/Train/')
test_dataset_path = Path('../../../../data/model/Patches/Test/')
growth_stages = ["germination", "tillering", "grand_growth", "ripening"]
X, X_test, y, y_test = [], [], [], []

for idx, stage in enumerate(growth_stages):
    stage_path = train_dataset_path / stage
    for img_file in os.listdir(stage_path):
        img_path = stage_path / img_file
        X.append(extract_features(img_path))
        y.append(idx)

X = np.array(X)
y = np.array(y)

for idx, stage in enumerate(growth_stages):
    stage_path = test_dataset_path / stage
    for img_file in os.listdir(stage_path):
        img_path = stage_path / img_file
        X_test.append(extract_features(img_path))
        y_test.append(idx)

X_test = np.array(X_test)
y_test = np.array(y_test)

# %% [markdown]
# #### Apply k-Fold Cross-Validation and GridSearchCV

# %%
# Define parameter grid for XGBoost
param_grid = {
    "n_estimators": [50, 100, 200],
    "max_depth": [3, 6, 10],
    "learning_rate": [0.01, 0.1, 0.2],
    "subsample": [0.8, 1.0],
    "colsample_bytree": [0.8, 1.0]
}

# Initialize XGBoost and GridSearchCV
xgb_model = XGBClassifier(use_label_encoder=False, eval_metric='mlogloss', random_state=42)
kf = KFold(n_splits=5, shuffle=True, random_state=42)

grid_search = GridSearchCV(xgb_model, param_grid, cv=kf, n_jobs=-1, verbose=2, return_train_score=True)

# Train model with cross-validation
grid_search.fit(X, y)

# Get the best model from Grid Search
best_model = grid_search.best_estimator_

# Best parameters
print(f"Best Parameters: {grid_search.best_params_}")

# Train the model on the entire training dataset
history = best_model.fit(X, y, eval_set=[(X, y), (X_test, y_test)], verbose=True)

# Plot training and test accuracy
eval_results = best_model.evals_result()
train_accuracy = eval_results['validation_0']['mlogloss']
test_accuracy = eval_results['validation_1']['mlogloss']

plt.figure(figsize=(8, 6))
plt.plot(train_accuracy, label='Train Accuracy')
plt.plot(test_accuracy, label='Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Log Loss')
plt.title('Training vs Test Accuracy')
plt.legend()
plt.savefig(Path("../../../../IMG/XGB_V21_accuracy_plot.png"))
plt.show()
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# c:\Users\hashi\anaconda3\envs\research_env\lib\site-packages\xgboost\core.py:158: UserWarning: [23:07:53] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Best Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.2, 'max_depth': 3, 'n_estimators': 100, 'subsample': 1.0}
# [0]	validation_0-mlogloss:1.16631	validation_1-mlogloss:1.16845
# [1]	validation_0-mlogloss:1.01502	validation_1-mlogloss:1.01842
# [2]	validation_0-mlogloss:0.90288	validation_1-mlogloss:0.90793
# [3]	validation_0-mlogloss:0.81804	validation_1-mlogloss:0.82394
# [4]	validation_0-mlogloss:0.75139	validation_1-mlogloss:0.75776
# [5]	validation_0-mlogloss:0.69937	validation_1-mlogloss:0.70664
# [6]	validation_0-mlogloss:0.65564	validation_1-mlogloss:0.66352
# [7]	validation_0-mlogloss:0.62114	validation_1-mlogloss:0.62943
# [8]	validation_0-mlogloss:0.59149	validation_1-mlogloss:0.60009
# [9]	validation_0-mlogloss:0.56756	validation_1-mlogloss:0.57666
# [10]	validation_0-mlogloss:0.54627	validation_1-mlogloss:0.55577
# [11]	validation_0-mlogloss:0.52841	validation_1-mlogloss:0.53831
# [12]	validation_0-mlogloss:0.51303	validation_1-mlogloss:0.52319
# [13]	validation_0-mlogloss:0.49925	validation_1-mlogloss:0.50956
# [14]	validation_0-mlogloss:0.48836	validation_1-mlogloss:0.49882
# [15]	validation_0-mlogloss:0.47884	validation_1-mlogloss:0.48962
# [16]	validation_0-mlogloss:0.47002	validation_1-mlogloss:0.48100
# [17]	validation_0-mlogloss:0.46249	validation_1-mlogloss:0.47348
# [18]	validation_0-mlogloss:0.45570	validation_1-mlogloss:0.46672
# [19]	validation_0-mlogloss:0.44985	validation_1-mlogloss:0.46115
# [20]	validation_0-mlogloss:0.44471	validation_1-mlogloss:0.45613
# [21]	validation_0-mlogloss:0.43980	validation_1-mlogloss:0.45156
# [22]	validation_0-mlogloss:0.43543	validation_1-mlogloss:0.44763
# [23]	validation_0-mlogloss:0.43052	validation_1-mlogloss:0.44293
# [24]	validation_0-mlogloss:0.42714	validation_1-mlogloss:0.43974
# [25]	validation_0-mlogloss:0.42406	validation_1-mlogloss:0.43684
# [26]	validation_0-mlogloss:0.42126	validation_1-mlogloss:0.43407
# [27]	validation_0-mlogloss:0.41788	validation_1-mlogloss:0.43085
# [28]	validation_0-mlogloss:0.41524	validation_1-mlogloss:0.42853
# [29]	validation_0-mlogloss:0.41273	validation_1-mlogloss:0.42619
# [30]	validation_0-mlogloss:0.41065	validation_1-mlogloss:0.42423
# [31]	validation_0-mlogloss:0.40841	validation_1-mlogloss:0.42199
# [32]	validation_0-mlogloss:0.40664	validation_1-mlogloss:0.42024
# [33]	validation_0-mlogloss:0.40450	validation_1-mlogloss:0.41834
# [34]	validation_0-mlogloss:0.40299	validation_1-mlogloss:0.41705
# [35]	validation_0-mlogloss:0.40158	validation_1-mlogloss:0.41558
# [36]	validation_0-mlogloss:0.40013	validation_1-mlogloss:0.41443
# [37]	validation_0-mlogloss:0.39872	validation_1-mlogloss:0.41322
# [38]	validation_0-mlogloss:0.39745	validation_1-mlogloss:0.41204
# [39]	validation_0-mlogloss:0.39622	validation_1-mlogloss:0.41086
# [40]	validation_0-mlogloss:0.39531	validation_1-mlogloss:0.41003
# [41]	validation_0-mlogloss:0.39406	validation_1-mlogloss:0.40922
# [42]	validation_0-mlogloss:0.39336	validation_1-mlogloss:0.40871
# [43]	validation_0-mlogloss:0.39240	validation_1-mlogloss:0.40795
# [44]	validation_0-mlogloss:0.39141	validation_1-mlogloss:0.40724
# [45]	validation_0-mlogloss:0.39065	validation_1-mlogloss:0.40665
# [46]	validation_0-mlogloss:0.38971	validation_1-mlogloss:0.40609
# [47]	validation_0-mlogloss:0.38886	validation_1-mlogloss:0.40550
# [48]	validation_0-mlogloss:0.38814	validation_1-mlogloss:0.40474
# [49]	validation_0-mlogloss:0.38765	validation_1-mlogloss:0.40444
# [50]	validation_0-mlogloss:0.38704	validation_1-mlogloss:0.40399
# [51]	validation_0-mlogloss:0.38631	validation_1-mlogloss:0.40329
# [52]	validation_0-mlogloss:0.38556	validation_1-mlogloss:0.40272
# [53]	validation_0-mlogloss:0.38509	validation_1-mlogloss:0.40225
# [54]	validation_0-mlogloss:0.38469	validation_1-mlogloss:0.40200
# [55]	validation_0-mlogloss:0.38416	validation_1-mlogloss:0.40164
# [56]	validation_0-mlogloss:0.38383	validation_1-mlogloss:0.40147
# [57]	validation_0-mlogloss:0.38338	validation_1-mlogloss:0.40116
# [58]	validation_0-mlogloss:0.38255	validation_1-mlogloss:0.40075
# [59]	validation_0-mlogloss:0.38195	validation_1-mlogloss:0.40050
# [60]	validation_0-mlogloss:0.38155	validation_1-mlogloss:0.40024
# [61]	validation_0-mlogloss:0.38104	validation_1-mlogloss:0.39998
# [62]	validation_0-mlogloss:0.38033	validation_1-mlogloss:0.39962
# [63]	validation_0-mlogloss:0.37991	validation_1-mlogloss:0.39940
# [64]	validation_0-mlogloss:0.37900	validation_1-mlogloss:0.39896
# [65]	validation_0-mlogloss:0.37849	validation_1-mlogloss:0.39877
# [66]	validation_0-mlogloss:0.37799	validation_1-mlogloss:0.39856
# [67]	validation_0-mlogloss:0.37774	validation_1-mlogloss:0.39840
# [68]	validation_0-mlogloss:0.37745	validation_1-mlogloss:0.39828
# [69]	validation_0-mlogloss:0.37693	validation_1-mlogloss:0.39790
# [70]	validation_0-mlogloss:0.37647	validation_1-mlogloss:0.39766
# [71]	validation_0-mlogloss:0.37589	validation_1-mlogloss:0.39743
# [72]	validation_0-mlogloss:0.37569	validation_1-mlogloss:0.39738
# [73]	validation_0-mlogloss:0.37521	validation_1-mlogloss:0.39704
# [74]	validation_0-mlogloss:0.37471	validation_1-mlogloss:0.39694
# [75]	validation_0-mlogloss:0.37414	validation_1-mlogloss:0.39692
# [76]	validation_0-mlogloss:0.37366	validation_1-mlogloss:0.39665
# [77]	validation_0-mlogloss:0.37336	validation_1-mlogloss:0.39658
# [78]	validation_0-mlogloss:0.37300	validation_1-mlogloss:0.39629
# [79]	validation_0-mlogloss:0.37282	validation_1-mlogloss:0.39621
# [80]	validation_0-mlogloss:0.37236	validation_1-mlogloss:0.39600
# [81]	validation_0-mlogloss:0.37193	validation_1-mlogloss:0.39588
# [82]	validation_0-mlogloss:0.37149	validation_1-mlogloss:0.39574
# [83]	validation_0-mlogloss:0.37100	validation_1-mlogloss:0.39579
# [84]	validation_0-mlogloss:0.37043	validation_1-mlogloss:0.39532
# [85]	validation_0-mlogloss:0.37012	validation_1-mlogloss:0.39523
# [86]	validation_0-mlogloss:0.36982	validation_1-mlogloss:0.39520
# [87]	validation_0-mlogloss:0.36958	validation_1-mlogloss:0.39510
# [88]	validation_0-mlogloss:0.36940	validation_1-mlogloss:0.39499
# [89]	validation_0-mlogloss:0.36907	validation_1-mlogloss:0.39485
# [90]	validation_0-mlogloss:0.36891	validation_1-mlogloss:0.39485
# [91]	validation_0-mlogloss:0.36864	validation_1-mlogloss:0.39472
# [92]	validation_0-mlogloss:0.36844	validation_1-mlogloss:0.39457
# [93]	validation_0-mlogloss:0.36824	validation_1-mlogloss:0.39453
# [94]	validation_0-mlogloss:0.36795	validation_1-mlogloss:0.39439
# [95]	validation_0-mlogloss:0.36778	validation_1-mlogloss:0.39431
# [96]	validation_0-mlogloss:0.36747	validation_1-mlogloss:0.39421
# [97]	validation_0-mlogloss:0.36727	validation_1-mlogloss:0.39417
# [98]	validation_0-mlogloss:0.36710	validation_1-mlogloss:0.39418
# [99]	validation_0-mlogloss:0.36683	validation_1-mlogloss:0.39394

# %% [markdown]
# #### Evaluate Model

# %%
# Evaluate the model on the test set
y_test_pred = best_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_test_pred)
test_report = classification_report(y_test, y_test_pred)

# Calculate additional metrics
test_precision = precision_score(y_test, y_test_pred, average='weighted')
test_recall = recall_score(y_test, y_test_pred, average='weighted')
test_f1 = f1_score(y_test, y_test_pred, average='weighted')
confusion = confusion_matrix(y_test, y_test_pred)

# Log confusion matrix as an image
plt.figure(figsize=(8, 6))
sns.heatmap(confusion, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.savefig(Path("../../../../IMG/XGB_V21_confusion_matrix.png")) # Save confusion matrix

# Print results
print(f"Test Accuracy: {test_accuracy}")
print(f"Test Precision: {test_precision}")
print(f"Test Recall: {test_recall}")
print(f"Test F1 Score: {test_f1}")
print(f"Classification Report:\n{test_report}")

# Save the best model to disk
XGB_model_v21 = Path("../../../../models/Map1/XGB_model_v21.joblib")
joblib.dump(best_model, XGB_model_v21)
print(f"Saved model to: {XGB_model_v21}")

# Evaluate using cross-validation accuracy
print(f"Best Cross-Validation Accuracy: {grid_search.best_score_ * 100:.2f}%")
# Out:
# Test Accuracy: 0.8318540433925049
# Test Precision: 0.8222078364012965
# Test Recall: 0.8318540433925049
# Test F1 Score: 0.8216181512788805
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.95      0.91      2071
#            1       0.68      0.41      0.52       499
#            2       0.82      0.86      0.84       984
#            3       0.76      0.69      0.73       502
#
#     accuracy                           0.83      4056
#    macro avg       0.79      0.73      0.75      4056
# weighted avg       0.82      0.83      0.82      4056
#
# Saved model to: ..\..\..\..\models\Map1\XGB_model_v21.joblib
# Best Cross-Validation Accuracy: 82.43%

# %% [markdown]
# #### Predict New Images

# %%
# Load the best model
model = joblib.load(Path("../../../../models/Map1/XGB_model_v21.joblib"))

def predict_growth_stage(image_path, model):
    features = extract_features(image_path)
    predicted_label = model.predict([features])[0]
    return growth_stages[predicted_label]

new_image = Path('../../../../data/model/Patches/Test/ripening/patch_70.tif')
predicted_stage = predict_growth_stage(new_image, model)
print(f"Predicted Growth Stage: {predicted_stage}")
print()
# Out:
# Predicted Growth Stage: ripening
