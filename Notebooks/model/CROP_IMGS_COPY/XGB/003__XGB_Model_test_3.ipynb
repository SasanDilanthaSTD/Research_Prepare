# %% [markdown]
# ## XGBoost modifications
#  - V1 : Use SMOTE

# %% [markdown]
# >- import packages

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import rasterio
from sklearn.model_selection import KFold, GridSearchCV
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report, f1_score, precision_score, recall_score, confusion_matrix
import joblib 
from pathlib import Path

# for data leveling
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline

# %% [markdown]
# >- Define function & modify

# %%
# Define functions to calculate NDVI and NDWI
def calculate_ndvi(nir, red):
    return (nir - red) / (nir + red + 1e-10)

def calculate_ndwi(nir, green):
    return (nir - green) / (nir + green + 1e-10)

'''
    Enhanced Feature Engineering:
        -  Current features (mean NDVI/NDWI) might be insufficient. Add:

'''
def extract_features(image_path):
    with rasterio.open(image_path) as src:
        bands = src.read()
        nir, red, green = bands[4], bands[2], bands[1]
        
        # Existing features
        ndvi = calculate_ndvi(nir, red)
        ndwi = calculate_ndwi(nir, green)
        
        # New features
        return [
            np.mean(ndvi), np.std(ndvi),  # Add standard deviation
            np.mean(ndwi), np.std(ndwi),
            np.percentile(nir, 75),  # Texture features
            np.mean(green > np.quantile(green, 0.75))  # Threshold features
        ]

# %% [markdown]
# >- load dataset with SMOTE

# %%
# Load dataset efficiently
train_dataset_path = Path('../../../../data/model/Patches/Train/')
test_dataset_path = Path('../../../../data/model/Patches/Test/')
growth_stages = ["germination", "tillering", "grand_growth", "ripening"]
X, X_test, y, y_test = [], [], [], []

for idx, stage in enumerate(growth_stages):
    stage_path = train_dataset_path / stage
    for img_file in os.listdir(stage_path):
        img_path = stage_path / img_file
        X.append(extract_features(img_path))
        y.append(idx)

X = np.array(X)
y = np.array(y)

# ADD SMOTE
smote = SMOTE(random_state=42)
X_res, y_res = smote.fit_resample(X, y)

for idx, stage in enumerate(growth_stages):
    stage_path = test_dataset_path / stage
    for img_file in os.listdir(stage_path):
        img_path = stage_path / img_file
        X_test.append(extract_features(img_path))
        y_test.append(idx)

X_test = np.array(X_test)
y_test = np.array(y_test)

# %% [markdown]
# >- setup model

# %%
# Define parameter grid for XGBoost
param_grid = {
    "n_estimators": [50, 100, 200],
    "max_depth": [3, 6, 10],
    "learning_rate": [0.01, 0.1, 0.2],
    "subsample": [0.8, 1.0],
    "colsample_bytree": [0.8, 1.0]
}

# Initialize XGBoost and GridSearchCV
xgb_model = XGBClassifier(
    objective='multi:softmax',
    num_class=4,
    use_label_encoder=False, 
    eval_metric='mlogloss', 
    random_state=42
    )

kf = KFold(n_splits=5, shuffle=True, random_state=42)

grid_search = GridSearchCV(xgb_model, param_grid, cv=kf, n_jobs=-1, verbose=2, return_train_score=True)

# Train model with cross-validation
# grid_search.fit(X, y)
grid_search.fit(X_res, y_res)

# Get the best model from Grid Search
best_model = grid_search.best_estimator_

# Best parameters
print(f"Best Parameters: {grid_search.best_params_}")

# Train the model on the entire training dataset
history = best_model.fit(X_res, y_res, eval_set=[(X_res, y_res), (X_test, y_test)], verbose=True)

# Plot training and test accuracy
eval_results = best_model.evals_result()
train_accuracy = eval_results['validation_0']['mlogloss']
test_accuracy = eval_results['validation_1']['mlogloss']

plt.figure(figsize=(8, 6))
plt.plot(train_accuracy, label='Train Accuracy')
plt.plot(test_accuracy, label='Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Log Loss')
plt.title('Training vs Test Accuracy')
plt.legend()
plt.savefig(Path("../../../../IMG/XGB_V31_accuracy_plot.png"))
plt.show()
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# c:\Users\hashi\anaconda3\envs\research_env\lib\site-packages\xgboost\core.py:158: UserWarning: [23:24:39] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Best Parameters: {'colsample_bytree': 1.0, 'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 200, 'subsample': 0.8}
# [0]	validation_0-mlogloss:1.21167	validation_1-mlogloss:1.22309
# [1]	validation_0-mlogloss:1.07054	validation_1-mlogloss:1.09201
# [2]	validation_0-mlogloss:0.95309	validation_1-mlogloss:0.98309
# [3]	validation_0-mlogloss:0.85365	validation_1-mlogloss:0.89107
# [4]	validation_0-mlogloss:0.76848	validation_1-mlogloss:0.81216
# [5]	validation_0-mlogloss:0.69454	validation_1-mlogloss:0.74452
# [6]	validation_0-mlogloss:0.62986	validation_1-mlogloss:0.68548
# c:\Users\hashi\anaconda3\envs\research_env\lib\site-packages\xgboost\core.py:158: UserWarning: [23:24:41] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [7]	validation_0-mlogloss:0.57298	validation_1-mlogloss:0.63378
# [8]	validation_0-mlogloss:0.52287	validation_1-mlogloss:0.58799
# [9]	validation_0-mlogloss:0.47850	validation_1-mlogloss:0.54764
# [10]	validation_0-mlogloss:0.43888	validation_1-mlogloss:0.51213
# [11]	validation_0-mlogloss:0.40343	validation_1-mlogloss:0.48026
# [12]	validation_0-mlogloss:0.37173	validation_1-mlogloss:0.45194
# [13]	validation_0-mlogloss:0.34319	validation_1-mlogloss:0.42681
# [14]	validation_0-mlogloss:0.31768	validation_1-mlogloss:0.40440
# [15]	validation_0-mlogloss:0.29471	validation_1-mlogloss:0.38428
# [16]	validation_0-mlogloss:0.27396	validation_1-mlogloss:0.36617
# [17]	validation_0-mlogloss:0.25516	validation_1-mlogloss:0.34993
# [18]	validation_0-mlogloss:0.23826	validation_1-mlogloss:0.33540
# [19]	validation_0-mlogloss:0.22303	validation_1-mlogloss:0.32206
# [20]	validation_0-mlogloss:0.20934	validation_1-mlogloss:0.30999
# [21]	validation_0-mlogloss:0.19690	validation_1-mlogloss:0.29946
# [22]	validation_0-mlogloss:0.18549	validation_1-mlogloss:0.28967
# [23]	validation_0-mlogloss:0.17546	validation_1-mlogloss:0.28109
# [24]	validation_0-mlogloss:0.16607	validation_1-mlogloss:0.27290
# [25]	validation_0-mlogloss:0.15748	validation_1-mlogloss:0.26563
# [26]	validation_0-mlogloss:0.14969	validation_1-mlogloss:0.25904
# [27]	validation_0-mlogloss:0.14269	validation_1-mlogloss:0.25337
# [28]	validation_0-mlogloss:0.13641	validation_1-mlogloss:0.24808
# [29]	validation_0-mlogloss:0.13053	validation_1-mlogloss:0.24324
# [30]	validation_0-mlogloss:0.12519	validation_1-mlogloss:0.23874
# [31]	validation_0-mlogloss:0.12017	validation_1-mlogloss:0.23499
# [32]	validation_0-mlogloss:0.11568	validation_1-mlogloss:0.23134
# [33]	validation_0-mlogloss:0.11172	validation_1-mlogloss:0.22802
# [34]	validation_0-mlogloss:0.10813	validation_1-mlogloss:0.22488
# [35]	validation_0-mlogloss:0.10483	validation_1-mlogloss:0.22199
# [36]	validation_0-mlogloss:0.10174	validation_1-mlogloss:0.21960
# [37]	validation_0-mlogloss:0.09896	validation_1-mlogloss:0.21730
# [38]	validation_0-mlogloss:0.09639	validation_1-mlogloss:0.21499
# [39]	validation_0-mlogloss:0.09399	validation_1-mlogloss:0.21300
# [40]	validation_0-mlogloss:0.09177	validation_1-mlogloss:0.21117
# [41]	validation_0-mlogloss:0.08968	validation_1-mlogloss:0.20956
# [42]	validation_0-mlogloss:0.08779	validation_1-mlogloss:0.20797
# [43]	validation_0-mlogloss:0.08609	validation_1-mlogloss:0.20656
# [44]	validation_0-mlogloss:0.08435	validation_1-mlogloss:0.20523
# [45]	validation_0-mlogloss:0.08281	validation_1-mlogloss:0.20397
# [46]	validation_0-mlogloss:0.08131	validation_1-mlogloss:0.20287
# [47]	validation_0-mlogloss:0.07991	validation_1-mlogloss:0.20193
# [48]	validation_0-mlogloss:0.07868	validation_1-mlogloss:0.20102
# [49]	validation_0-mlogloss:0.07742	validation_1-mlogloss:0.20009
# [50]	validation_0-mlogloss:0.07619	validation_1-mlogloss:0.19928
# [51]	validation_0-mlogloss:0.07529	validation_1-mlogloss:0.19827
# [52]	validation_0-mlogloss:0.07437	validation_1-mlogloss:0.19779
# [53]	validation_0-mlogloss:0.07347	validation_1-mlogloss:0.19718
# [54]	validation_0-mlogloss:0.07271	validation_1-mlogloss:0.19655
# [55]	validation_0-mlogloss:0.07187	validation_1-mlogloss:0.19621
# [56]	validation_0-mlogloss:0.07094	validation_1-mlogloss:0.19549
# [57]	validation_0-mlogloss:0.07030	validation_1-mlogloss:0.19501
# [58]	validation_0-mlogloss:0.06948	validation_1-mlogloss:0.19446
# [59]	validation_0-mlogloss:0.06884	validation_1-mlogloss:0.19387
# [60]	validation_0-mlogloss:0.06817	validation_1-mlogloss:0.19335
# [61]	validation_0-mlogloss:0.06757	validation_1-mlogloss:0.19325
# [62]	validation_0-mlogloss:0.06695	validation_1-mlogloss:0.19273
# [63]	validation_0-mlogloss:0.06629	validation_1-mlogloss:0.19249
# [64]	validation_0-mlogloss:0.06550	validation_1-mlogloss:0.19201
# [65]	validation_0-mlogloss:0.06506	validation_1-mlogloss:0.19192
# [66]	validation_0-mlogloss:0.06465	validation_1-mlogloss:0.19162
# [67]	validation_0-mlogloss:0.06395	validation_1-mlogloss:0.19131
# [68]	validation_0-mlogloss:0.06336	validation_1-mlogloss:0.19116
# [69]	validation_0-mlogloss:0.06275	validation_1-mlogloss:0.19101
# [70]	validation_0-mlogloss:0.06223	validation_1-mlogloss:0.19091
# [71]	validation_0-mlogloss:0.06158	validation_1-mlogloss:0.19088
# [72]	validation_0-mlogloss:0.06112	validation_1-mlogloss:0.19068
# [73]	validation_0-mlogloss:0.06058	validation_1-mlogloss:0.19033
# [74]	validation_0-mlogloss:0.06003	validation_1-mlogloss:0.19007
# [75]	validation_0-mlogloss:0.05923	validation_1-mlogloss:0.18973
# [76]	validation_0-mlogloss:0.05865	validation_1-mlogloss:0.18938
# [77]	validation_0-mlogloss:0.05810	validation_1-mlogloss:0.18924
# [78]	validation_0-mlogloss:0.05774	validation_1-mlogloss:0.18908
# [79]	validation_0-mlogloss:0.05732	validation_1-mlogloss:0.18907
# [80]	validation_0-mlogloss:0.05689	validation_1-mlogloss:0.18900
# [81]	validation_0-mlogloss:0.05623	validation_1-mlogloss:0.18896
# [82]	validation_0-mlogloss:0.05574	validation_1-mlogloss:0.18892
# [83]	validation_0-mlogloss:0.05534	validation_1-mlogloss:0.18877
# [84]	validation_0-mlogloss:0.05485	validation_1-mlogloss:0.18895
# [85]	validation_0-mlogloss:0.05446	validation_1-mlogloss:0.18889
# [86]	validation_0-mlogloss:0.05388	validation_1-mlogloss:0.18862
# [87]	validation_0-mlogloss:0.05351	validation_1-mlogloss:0.18872
# [88]	validation_0-mlogloss:0.05310	validation_1-mlogloss:0.18887
# [89]	validation_0-mlogloss:0.05276	validation_1-mlogloss:0.18882
# [90]	validation_0-mlogloss:0.05235	validation_1-mlogloss:0.18888
# [91]	validation_0-mlogloss:0.05176	validation_1-mlogloss:0.18890
# [92]	validation_0-mlogloss:0.05116	validation_1-mlogloss:0.18916
# [93]	validation_0-mlogloss:0.05059	validation_1-mlogloss:0.18911
# [94]	validation_0-mlogloss:0.05002	validation_1-mlogloss:0.18948
# [95]	validation_0-mlogloss:0.04948	validation_1-mlogloss:0.18964
# [96]	validation_0-mlogloss:0.04910	validation_1-mlogloss:0.18974
# [97]	validation_0-mlogloss:0.04876	validation_1-mlogloss:0.19001
# [98]	validation_0-mlogloss:0.04840	validation_1-mlogloss:0.19015
# [99]	validation_0-mlogloss:0.04793	validation_1-mlogloss:0.19032
# [100]	validation_0-mlogloss:0.04764	validation_1-mlogloss:0.19049
# [101]	validation_0-mlogloss:0.04715	validation_1-mlogloss:0.19071
# [102]	validation_0-mlogloss:0.04666	validation_1-mlogloss:0.19085
# [103]	validation_0-mlogloss:0.04623	validation_1-mlogloss:0.19106
# [104]	validation_0-mlogloss:0.04563	validation_1-mlogloss:0.19130
# [105]	validation_0-mlogloss:0.04515	validation_1-mlogloss:0.19171
# [106]	validation_0-mlogloss:0.04487	validation_1-mlogloss:0.19188
# [107]	validation_0-mlogloss:0.04443	validation_1-mlogloss:0.19181
# [108]	validation_0-mlogloss:0.04406	validation_1-mlogloss:0.19223
# [109]	validation_0-mlogloss:0.04370	validation_1-mlogloss:0.19239
# [110]	validation_0-mlogloss:0.04351	validation_1-mlogloss:0.19253
# [111]	validation_0-mlogloss:0.04309	validation_1-mlogloss:0.19255
# [112]	validation_0-mlogloss:0.04263	validation_1-mlogloss:0.19298
# [113]	validation_0-mlogloss:0.04235	validation_1-mlogloss:0.19309
# [114]	validation_0-mlogloss:0.04194	validation_1-mlogloss:0.19333
# [115]	validation_0-mlogloss:0.04154	validation_1-mlogloss:0.19347
# [116]	validation_0-mlogloss:0.04109	validation_1-mlogloss:0.19390
# [117]	validation_0-mlogloss:0.04078	validation_1-mlogloss:0.19418
# [118]	validation_0-mlogloss:0.04044	validation_1-mlogloss:0.19441
# [119]	validation_0-mlogloss:0.04014	validation_1-mlogloss:0.19458
# [120]	validation_0-mlogloss:0.03971	validation_1-mlogloss:0.19506
# [121]	validation_0-mlogloss:0.03934	validation_1-mlogloss:0.19523
# [122]	validation_0-mlogloss:0.03901	validation_1-mlogloss:0.19533
# [123]	validation_0-mlogloss:0.03864	validation_1-mlogloss:0.19541
# [124]	validation_0-mlogloss:0.03834	validation_1-mlogloss:0.19571
# [125]	validation_0-mlogloss:0.03795	validation_1-mlogloss:0.19604
# [126]	validation_0-mlogloss:0.03763	validation_1-mlogloss:0.19623
# [127]	validation_0-mlogloss:0.03726	validation_1-mlogloss:0.19663
# [128]	validation_0-mlogloss:0.03709	validation_1-mlogloss:0.19675
# [129]	validation_0-mlogloss:0.03692	validation_1-mlogloss:0.19669
# [130]	validation_0-mlogloss:0.03661	validation_1-mlogloss:0.19690
# [131]	validation_0-mlogloss:0.03645	validation_1-mlogloss:0.19691
# [132]	validation_0-mlogloss:0.03631	validation_1-mlogloss:0.19712
# [133]	validation_0-mlogloss:0.03602	validation_1-mlogloss:0.19741
# [134]	validation_0-mlogloss:0.03584	validation_1-mlogloss:0.19764
# [135]	validation_0-mlogloss:0.03568	validation_1-mlogloss:0.19769
# [136]	validation_0-mlogloss:0.03537	validation_1-mlogloss:0.19791
# [137]	validation_0-mlogloss:0.03516	validation_1-mlogloss:0.19798
# [138]	validation_0-mlogloss:0.03494	validation_1-mlogloss:0.19824
# [139]	validation_0-mlogloss:0.03469	validation_1-mlogloss:0.19842
# [140]	validation_0-mlogloss:0.03440	validation_1-mlogloss:0.19866
# [141]	validation_0-mlogloss:0.03417	validation_1-mlogloss:0.19894
# [142]	validation_0-mlogloss:0.03408	validation_1-mlogloss:0.19911
# [143]	validation_0-mlogloss:0.03390	validation_1-mlogloss:0.19917
# [144]	validation_0-mlogloss:0.03356	validation_1-mlogloss:0.19957
# [145]	validation_0-mlogloss:0.03337	validation_1-mlogloss:0.19969
# [146]	validation_0-mlogloss:0.03309	validation_1-mlogloss:0.19974
# [147]	validation_0-mlogloss:0.03293	validation_1-mlogloss:0.19987
# [148]	validation_0-mlogloss:0.03260	validation_1-mlogloss:0.20007
# [149]	validation_0-mlogloss:0.03231	validation_1-mlogloss:0.20022
# [150]	validation_0-mlogloss:0.03209	validation_1-mlogloss:0.20045
# [151]	validation_0-mlogloss:0.03191	validation_1-mlogloss:0.20083
# [152]	validation_0-mlogloss:0.03169	validation_1-mlogloss:0.20102
# [153]	validation_0-mlogloss:0.03154	validation_1-mlogloss:0.20124
# [154]	validation_0-mlogloss:0.03126	validation_1-mlogloss:0.20153
# [155]	validation_0-mlogloss:0.03100	validation_1-mlogloss:0.20171
# [156]	validation_0-mlogloss:0.03084	validation_1-mlogloss:0.20195
# [157]	validation_0-mlogloss:0.03065	validation_1-mlogloss:0.20236
# [158]	validation_0-mlogloss:0.03041	validation_1-mlogloss:0.20252
# [159]	validation_0-mlogloss:0.03014	validation_1-mlogloss:0.20292
# [160]	validation_0-mlogloss:0.02993	validation_1-mlogloss:0.20315
# [161]	validation_0-mlogloss:0.02970	validation_1-mlogloss:0.20345
# [162]	validation_0-mlogloss:0.02956	validation_1-mlogloss:0.20370
# [163]	validation_0-mlogloss:0.02936	validation_1-mlogloss:0.20407
# [164]	validation_0-mlogloss:0.02918	validation_1-mlogloss:0.20412
# [165]	validation_0-mlogloss:0.02889	validation_1-mlogloss:0.20432
# [166]	validation_0-mlogloss:0.02873	validation_1-mlogloss:0.20425
# [167]	validation_0-mlogloss:0.02857	validation_1-mlogloss:0.20434
# [168]	validation_0-mlogloss:0.02840	validation_1-mlogloss:0.20451
# [169]	validation_0-mlogloss:0.02814	validation_1-mlogloss:0.20461
# [170]	validation_0-mlogloss:0.02794	validation_1-mlogloss:0.20501
# [171]	validation_0-mlogloss:0.02780	validation_1-mlogloss:0.20497
# [172]	validation_0-mlogloss:0.02753	validation_1-mlogloss:0.20496
# [173]	validation_0-mlogloss:0.02733	validation_1-mlogloss:0.20528
# [174]	validation_0-mlogloss:0.02710	validation_1-mlogloss:0.20548
# [175]	validation_0-mlogloss:0.02691	validation_1-mlogloss:0.20580
# [176]	validation_0-mlogloss:0.02672	validation_1-mlogloss:0.20588
# [177]	validation_0-mlogloss:0.02655	validation_1-mlogloss:0.20599
# [178]	validation_0-mlogloss:0.02640	validation_1-mlogloss:0.20637
# [179]	validation_0-mlogloss:0.02631	validation_1-mlogloss:0.20647
# [180]	validation_0-mlogloss:0.02614	validation_1-mlogloss:0.20654
# [181]	validation_0-mlogloss:0.02594	validation_1-mlogloss:0.20670
# [182]	validation_0-mlogloss:0.02572	validation_1-mlogloss:0.20689
# [183]	validation_0-mlogloss:0.02559	validation_1-mlogloss:0.20726
# [184]	validation_0-mlogloss:0.02543	validation_1-mlogloss:0.20736
# [185]	validation_0-mlogloss:0.02533	validation_1-mlogloss:0.20734
# [186]	validation_0-mlogloss:0.02518	validation_1-mlogloss:0.20773
# [187]	validation_0-mlogloss:0.02510	validation_1-mlogloss:0.20779
# [188]	validation_0-mlogloss:0.02492	validation_1-mlogloss:0.20797
# [189]	validation_0-mlogloss:0.02480	validation_1-mlogloss:0.20812
# [190]	validation_0-mlogloss:0.02457	validation_1-mlogloss:0.20854
# [191]	validation_0-mlogloss:0.02445	validation_1-mlogloss:0.20870
# [192]	validation_0-mlogloss:0.02432	validation_1-mlogloss:0.20886
# [193]	validation_0-mlogloss:0.02416	validation_1-mlogloss:0.20913
# [194]	validation_0-mlogloss:0.02405	validation_1-mlogloss:0.20932
# [195]	validation_0-mlogloss:0.02389	validation_1-mlogloss:0.20943
# [196]	validation_0-mlogloss:0.02379	validation_1-mlogloss:0.20960
# [197]	validation_0-mlogloss:0.02373	validation_1-mlogloss:0.20978
# [198]	validation_0-mlogloss:0.02359	validation_1-mlogloss:0.20989
# [199]	validation_0-mlogloss:0.02351	validation_1-mlogloss:0.20991

# %% [markdown]
# >- evaluate model

# %%
# Evaluate the model on the test set
y_test_pred = best_model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_test_pred)
test_report = classification_report(y_test, y_test_pred)

# Calculate additional metrics
test_precision = precision_score(y_test, y_test_pred, average='weighted')
test_recall = recall_score(y_test, y_test_pred, average='weighted')
test_f1 = f1_score(y_test, y_test_pred, average='weighted')
confusion = confusion_matrix(y_test, y_test_pred)

# Log confusion matrix as an image
plt.figure(figsize=(8, 6))
sns.heatmap(confusion, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.savefig(Path("../../../../IMG/XGB_V31_confusion_matrix.png")) # Save confusion matrix

# Print results
print(f"Test Accuracy: {test_accuracy}")
print(f"Test Precision: {test_precision}")
print(f"Test Recall: {test_recall}")
print(f"Test F1 Score: {test_f1}")
print(f"Classification Report:\n{test_report}")

# Save the best model to disk
XGB_model_v31 = Path("../../../../models/Map1/XGB_model_v31.joblib")
joblib.dump(best_model, XGB_model_v31)
print(f"Saved model to: {XGB_model_v31}")

# Evaluate using cross-validation accuracy
print(f"Best Cross-Validation Accuracy: {grid_search.best_score_ * 100:.2f}%")
# Out:
# Test Accuracy: 0.9201183431952663
# Test Precision: 0.9347796624956086
# Test Recall: 0.9201183431952663
# Test F1 Score: 0.9243734357864213
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.88      0.92      2071
#            1       0.64      0.87      0.74       499
#            2       1.00      0.99      0.99       984
#            3       0.99      0.99      0.99       502
#
#     accuracy                           0.92      4056
#    macro avg       0.90      0.93      0.91      4056
# weighted avg       0.93      0.92      0.92      4056
#
# Saved model to: ..\..\..\..\models\Map1\XGB_model_v31.joblib
# Best Cross-Validation Accuracy: 95.75%

# %% [markdown]
# >- predict

# %%
# Load the best model
model = joblib.load(Path("../../../../models/Map1/XGB_model_v31.joblib"))

def predict_growth_stage(image_path, model):
    features = extract_features(image_path)
    predicted_label = model.predict([features])[0]
    return growth_stages[predicted_label]

new_image = Path('../../../../data/model/Patches/Test/ripening/patch_70.tif')
predicted_stage = predict_growth_stage(new_image, model)
print(f"Predicted Growth Stage: {predicted_stage}")
print()
# Out:
# Predicted Growth Stage: ripening
